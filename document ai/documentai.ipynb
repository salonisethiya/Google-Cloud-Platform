# %% [markdown]
# ## Importing necessary libraries

# %%
import os
from google.cloud import documentai_v1beta2 as documentai
import matplotlib.pyplot as plt
import cv2
import argparse
import io
import json
import numpy
import six
import re
from google.cloud import storage
import pandas as pd

# %% [markdown]
# ## Setting path to json key

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/home/affine/GCP/downloaded_key.json"

# %% [markdown]
# # 1) Parsing documents containing forms

# %% [markdown]
# - Document AI can detect and parse text from PDF, TIFF, GIF files stored in Cloud Storage, including text that contains unstructured data in the form documents.
#
#
# - Request document processing from a smaller file (<=5 pages) using the process method, and larger file requests (files with a large number of pages) use the batchProcess method. The status of batch (asynchronous) requests can be checked using the operations resources.

# %% [markdown]
# ## a) Small file online processing

# %% [markdown]
# - Synchronous ("online") requests target a document with a small number of pages and size (<=5 pages, < 20MB) stored in Cloud Storage.
#
# - Synchronous requests immediately return a response inline.

# %% [markdown]
# ### Parsing pdf form

# %% [markdown]
# To parse forms:
#
#
# - Instantiate the document understanding service client.
#
# - Specifying the Google Cloud Storage location where the input file will be read from.
#
# - Specifying the desired input location and metadata.
#
# - We can improve form parsing results by providing key-value pair hints.
#
# - Set the parameters to control form extraction behavior.
#
# - Request to process one document.
#
# - Use process_document method to send request to API.

# %% [markdown]
# For Parsing pdf forms: mime type used is application/pdf

# %%
def parse_form_pdf(project_id,input_uri):
    """Parse a form"""

    client = documentai.DocumentUnderstandingServiceClient()

    gcs_source = documentai.types.GcsSource(uri=input_uri)

    # mime_type can be application/pdf, image/tiff,
    # and image/gif, or application/json
    input_config = documentai.types.InputConfig(
        gcs_source=gcs_source, mime_type='application/pdf')

    # Improve form parsing results by providing key-value pair hints.
    # For each key hint, key is text that is likely to appear in the
    # document as a form field name (i.e. "DOB").
    # Value types are optional, but can be one or more of:
    # ADDRESS, LOCATION, ORGANIZATION, PERSON, PHONE_NUMBER, ID,
    # NUMBER, EMAIL, PRICE, TERMS, DATE, NAME
    key_value_pair_hints = [
        documentai.types.KeyValuePairHint(key='Emergency Contact',
                                          value_types=['NAME']),
        documentai.types.KeyValuePairHint(
            key='Referred By')
    ]

    # Setting enabled=True enables form extraction
    form_extraction_params = documentai.types.FormExtractionParams(
        enabled=True, key_value_pair_hints=key_value_pair_hints)

    # Location can be 'us' or 'eu'
    parent = 'projects/{}/locations/us'.format(project_id)
    request = documentai.types.ProcessDocumentRequest(
        parent=parent,
        input_config=input_config,
        form_extraction_params=form_extraction_params)

    document = client.process_document(request=request)
    print('document: \n',document)
    
    def _get_text(el):
        """Doc AI identifies form fields by their offsets
        in document text. This function converts offsets
        to text snippets.
        """
        response = ''
        # If a text segment spans several lines, it will
        # be stored in different text segments.
        for segment in el.text_anchor.text_segments:
            start_index = segment.start_index
            end_index = segment.end_index
            response += document.text[start_index:end_index]
        return response

    for page in document.pages:
        print('Page number: {}'.format(page.page_number))
        for form_field in page.form_fields:
            print('Field Name: {}\tConfidence: {}'.format(
                _get_text(form_field.field_name),
                form_field.field_name.confidence))
            print('Field Value: {}\tConfidence: {}'.format(
                _get_text(form_field.field_value),
                form_field.field_value.confidence))

# %%
# calling above function

parse_form_pdf("project-001-285307","gs://bucket0406/form.pdf")
# Out:
# document:
#  mime_type: "application/pdf"
# text: "FakeDoc M.D.\nHEALTH INTAKE FORM\nPlease fill out the questionnaire carefully. The information you provide will be used to complete\nyour health profile and will be kept confidential.\nDate:\n9/14/19\nName: Sally Walker\nDOB: 09/04/1986\nAddress: 24 Barney Lane City: Tonaco State: NJ Zip: 07082\nEmail: Sally, waller@cmail.com_Phone #:_(906) 917-3486\nGender: _F\nSingle Occupation: Software Engineer\nReferred By: None\nEmergency Contact: Eva Walker Emergency Contact Phone: (906)334-89766\nMarital Status:\nDescribe your medical concerns (symptoms, diagnoses, etc):\nRanny nose, mucas in thoat, weakness,\naches, chills, tired\nAre you currently taking any medication? (If yes, please describe):\nVyvanse (25mg) daily for attention\n"
# pages {
#   page_number: 1
#   dimension {
#     width: 418.0
#     height: 492.0
#     unit: "points"
#   }
#   layout {
#     text_anchor {
#       text_segments {
#         end_index: 716
#       }
#     }
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 418
#       }
#       vertices {
#         x: 418
#         y: 492
#       }
#       vertices {
#         y: 492
#       }
#       normalized_vertices {
#       }
#       normalized_vertices {
#         x: 1.0
#       }
#       normalized_vertices {
#         x: 1.0
#         y: 1.0
#       }
#       normalized_vertices {
#         y: 1.0
#       }
#     }
#     orientation: 1
#   }
#   detected_languages {
#     language_code: "en"
#     confidence: 0.9700000286102295
#   }
#   detected_languages {
#     language_code: "cs"
#     confidence: 0.019999999552965164
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           end_index: 181
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11924119293689728
#           y: 0.021688971668481827
#         }
#         normalized_vertices {
#           x: 0.8504065275192261
#           y: 0.021688971668481827
#         }
#         normalized_vertices {
#           x: 0.8504065275192261
#           y: 0.11121366173028946
#         }
#         normalized_vertices {
#           x: 0.11924119293689728
#           y: 0.11121366173028946
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 181
#           end_index: 187
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11869918555021286
#           y: 0.13797877728939056
#         }
#         normalized_vertices {
#           x: 0.1696476936340332
#           y: 0.13797877728939056
#         }
#         normalized_vertices {
#           x: 0.1696476936340332
#           y: 0.1532071977853775
#         }
#         normalized_vertices {
#           x: 0.11869918555021286
#           y: 0.1532071977853775
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 187
#           end_index: 479
#         }
#       }
#       confidence: 0.9100000262260437
#       bounding_poly {
#         normalized_vertices {
#           x: 0.10731707513332367
#           y: 0.1199815422296524
#         }
#         normalized_vertices {
#           x: 0.9479674696922302
#           y: 0.10290724784135818
#         }
#         normalized_vertices {
#           x: 0.9566395878791809
#           y: 0.41947391629219055
#         }
#         normalized_vertices {
#           x: 0.11598916351795197
#           y: 0.43654823303222656
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 0.9200000166893005
#     }
#     detected_languages {
#       language_code: "cs"
#       confidence: 0.05999999865889549
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 479
#           end_index: 495
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.30027100443840027
#           y: 0.3124134838581085
#         }
#         normalized_vertices {
#           x: 0.4411924183368683
#           y: 0.3124134838581085
#         }
#         normalized_vertices {
#           x: 0.4411924183368683
#           y: 0.32810336351394653
#         }
#         normalized_vertices {
#           x: 0.30027100443840027
#           y: 0.32810336351394653
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 495
#           end_index: 554
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11815717816352844
#           y: 0.4420858323574066
#         }
#         normalized_vertices {
#           x: 0.7262872457504272
#           y: 0.4420858323574066
#         }
#         normalized_vertices {
#           x: 0.7262872457504272
#           y: 0.462851881980896
#         }
#         normalized_vertices {
#           x: 0.11815717816352844
#           y: 0.462851881980896
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 554
#           end_index: 613
#         }
#       }
#       confidence: 0.9300000071525574
#       bounding_poly {
#         normalized_vertices {
#           x: 0.15880759060382843
#           y: 0.4799261689186096
#         }
#         normalized_vertices {
#           x: 0.8157181739807129
#           y: 0.4799261689186096
#         }
#         normalized_vertices {
#           x: 0.8157181739807129
#           y: 0.5639132261276245
#         }
#         normalized_vertices {
#           x: 0.15880759060382843
#           y: 0.5639132261276245
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 613
#           end_index: 681
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11815717816352844
#           y: 0.7466543316841125
#         }
#         normalized_vertices {
#           x: 0.783197820186615
#           y: 0.7466543316841125
#         }
#         normalized_vertices {
#           x: 0.783197820186615
#           y: 0.7674204111099243
#         }
#         normalized_vertices {
#           x: 0.11815717816352844
#           y: 0.7674204111099243
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 681
#           end_index: 716
#         }
#       }
#       confidence: 0.9100000262260437
#       bounding_poly {
#         normalized_vertices {
#           x: 0.1642276495695114
#           y: 0.7784956097602844
#         }
#         normalized_vertices {
#           x: 0.7322493195533752
#           y: 0.7724965214729309
#         }
#         normalized_vertices {
#           x: 0.7327913045883179
#           y: 0.8227964639663696
#         }
#         normalized_vertices {
#           x: 0.16476964950561523
#           y: 0.8287955522537231
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           end_index: 13
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11924119293689728
#           y: 0.021688971668481827
#         }
#         normalized_vertices {
#           x: 0.23631435632705688
#           y: 0.021688971668481827
#         }
#         normalized_vertices {
#           x: 0.23631435632705688
#           y: 0.03507152572274208
#         }
#         normalized_vertices {
#           x: 0.11924119293689728
#           y: 0.03507152572274208
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 13
#           end_index: 181
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12086720764636993
#           y: 0.044300876557826996
#         }
#         normalized_vertices {
#           x: 0.8504065275192261
#           y: 0.044300876557826996
#         }
#         normalized_vertices {
#           x: 0.8504065275192261
#           y: 0.11121366173028946
#         }
#         normalized_vertices {
#           x: 0.12086720764636993
#           y: 0.11121366173028946
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 181
#           end_index: 187
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11869918555021286
#           y: 0.13797877728939056
#         }
#         normalized_vertices {
#           x: 0.1696476936340332
#           y: 0.13797877728939056
#         }
#         normalized_vertices {
#           x: 0.1696476936340332
#           y: 0.1532071977853775
#         }
#         normalized_vertices {
#           x: 0.11869918555021286
#           y: 0.1532071977853775
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 187
#           end_index: 214
#         }
#       }
#       confidence: 0.8999999761581421
#       bounding_poly {
#         normalized_vertices {
#           x: 0.10731707513332367
#           y: 0.12736502289772034
#         }
#         normalized_vertices {
#           x: 0.41680216789245605
#           y: 0.11398246139287949
#         }
#         normalized_vertices {
#           x: 0.42276424169540405
#           y: 0.20950622856616974
#         }
#         normalized_vertices {
#           x: 0.11327913403511047
#           y: 0.22288878262043
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 0.699999988079071
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 214
#           end_index: 354
#         }
#       }
#       confidence: 0.8899999856948853
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11490514874458313
#           y: 0.17258882522583008
#         }
#         normalized_vertices {
#           x: 0.9035230278968811
#           y: 0.1628980189561844
#         }
#         normalized_vertices {
#           x: 0.9062330722808838
#           y: 0.32441163063049316
#         }
#         normalized_vertices {
#           x: 0.11761517822742462
#           y: 0.33410245180130005
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 0.8799999952316284
#     }
#     detected_languages {
#       language_code: "cs"
#       confidence: 0.11999999731779099
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 354
#           end_index: 479
#         }
#       }
#       confidence: 0.9300000071525574
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11815717816352844
#           y: 0.3036455810070038
#         }
#         normalized_vertices {
#           x: 0.9533875584602356
#           y: 0.29903092980384827
#         }
#         normalized_vertices {
#           x: 0.9544715285301208
#           y: 0.41947391629219055
#         }
#         normalized_vertices {
#           x: 0.11924119293689728
#           y: 0.42408859729766846
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 479
#           end_index: 495
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.30027100443840027
#           y: 0.3124134838581085
#         }
#         normalized_vertices {
#           x: 0.4411924183368683
#           y: 0.3124134838581085
#         }
#         normalized_vertices {
#           x: 0.4411924183368683
#           y: 0.32810336351394653
#         }
#         normalized_vertices {
#           x: 0.30027100443840027
#           y: 0.32810336351394653
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 495
#           end_index: 554
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11815717816352844
#           y: 0.4420858323574066
#         }
#         normalized_vertices {
#           x: 0.7262872457504272
#           y: 0.4420858323574066
#         }
#         normalized_vertices {
#           x: 0.7262872457504272
#           y: 0.462851881980896
#         }
#         normalized_vertices {
#           x: 0.11815717816352844
#           y: 0.462851881980896
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 554
#           end_index: 613
#         }
#       }
#       confidence: 0.9300000071525574
#       bounding_poly {
#         normalized_vertices {
#           x: 0.15880759060382843
#           y: 0.4799261689186096
#         }
#         normalized_vertices {
#           x: 0.8157181739807129
#           y: 0.4799261689186096
#         }
#         normalized_vertices {
#           x: 0.8157181739807129
#           y: 0.5639132261276245
#         }
#         normalized_vertices {
#           x: 0.15880759060382843
#           y: 0.5639132261276245
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 613
#           end_index: 681
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11815717816352844
#           y: 0.7466543316841125
#         }
#         normalized_vertices {
#           x: 0.783197820186615
#           y: 0.7466543316841125
#         }
#         normalized_vertices {
#           x: 0.783197820186615
#           y: 0.7674204111099243
#         }
#         normalized_vertices {
#           x: 0.11815717816352844
#           y: 0.7674204111099243
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 681
#           end_index: 716
#         }
#       }
#       confidence: 0.9100000262260437
#       bounding_poly {
#         normalized_vertices {
#           x: 0.1642276495695114
#           y: 0.7784956097602844
#         }
#         normalized_vertices {
#           x: 0.7322493195533752
#           y: 0.7724965214729309
#         }
#         normalized_vertices {
#           x: 0.7327913045883179
#           y: 0.8227964639663696
#         }
#         normalized_vertices {
#           x: 0.16476964950561523
#           y: 0.8287955522537231
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           end_index: 13
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11924119293689728
#           y: 0.021688971668481827
#         }
#         normalized_vertices {
#           x: 0.23631435632705688
#           y: 0.021688971668481827
#         }
#         normalized_vertices {
#           x: 0.23631435632705688
#           y: 0.03507152572274208
#         }
#         normalized_vertices {
#           x: 0.11924119293689728
#           y: 0.03507152572274208
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 13
#           end_index: 32
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.3604336082935333
#           y: 0.044300876557826996
#         }
#         normalized_vertices {
#           x: 0.6352303624153137
#           y: 0.044300876557826996
#         }
#         normalized_vertices {
#           x: 0.6352303624153137
#           y: 0.06229810789227486
#         }
#         normalized_vertices {
#           x: 0.3604336082935333
#           y: 0.06229810789227486
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 32
#           end_index: 130
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12140921503305435
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.8504065275192261
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.8504065275192261
#           y: 0.09090909361839294
#         }
#         normalized_vertices {
#           x: 0.12140921503305435
#           y: 0.09090909361839294
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 130
#           end_index: 181
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12086720764636993
#           y: 0.09275496006011963
#         }
#         normalized_vertices {
#           x: 0.4850948452949524
#           y: 0.09275496006011963
#         }
#         normalized_vertices {
#           x: 0.4850948452949524
#           y: 0.11121366173028946
#         }
#         normalized_vertices {
#           x: 0.12086720764636993
#           y: 0.11121366173028946
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 181
#           end_index: 187
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11869918555021286
#           y: 0.13797877728939056
#         }
#         normalized_vertices {
#           x: 0.1696476936340332
#           y: 0.13797877728939056
#         }
#         normalized_vertices {
#           x: 0.1696476936340332
#           y: 0.1532071977853775
#         }
#         normalized_vertices {
#           x: 0.11869918555021286
#           y: 0.1532071977853775
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 187
#           end_index: 195
#         }
#       }
#       confidence: 0.7300000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.20379403233528137
#           y: 0.12136594206094742
#         }
#         normalized_vertices {
#           x: 0.3387534022331238
#           y: 0.12136594206094742
#         }
#         normalized_vertices {
#           x: 0.3387534022331238
#           y: 0.16474388539791107
#         }
#         normalized_vertices {
#           x: 0.20379403233528137
#           y: 0.16474388539791107
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 195
#           end_index: 214
#         }
#       }
#       confidence: 0.9700000286102295
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11002709716558456
#           y: 0.15736040472984314
#         }
#         normalized_vertices {
#           x: 0.42222222685813904
#           y: 0.15736040472984314
#         }
#         normalized_vertices {
#           x: 0.42222222685813904
#           y: 0.22288878262043
#         }
#         normalized_vertices {
#           x: 0.11002709716558456
#           y: 0.22288878262043
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 214
#           end_index: 230
#         }
#       }
#       confidence: 0.9200000166893005
#       bounding_poly {
#         normalized_vertices {
#           x: 0.648238480091095
#           y: 0.16335947811603546
#         }
#         normalized_vertices {
#           x: 0.9040650129318237
#           y: 0.16335947811603546
#         }
#         normalized_vertices {
#           x: 0.9040650129318237
#           y: 0.20304568111896515
#         }
#         normalized_vertices {
#           x: 0.648238480091095
#           y: 0.20304568111896515
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 230
#           end_index: 288
#         }
#       }
#       confidence: 0.8999999761581421
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12303522974252701
#           y: 0.22058144211769104
#         }
#         normalized_vertices {
#           x: 0.8970189690589905
#           y: 0.22058144211769104
#         }
#         normalized_vertices {
#           x: 0.8970189690589905
#           y: 0.24919243156909943
#         }
#         normalized_vertices {
#           x: 0.12303522974252701
#           y: 0.24919243156909943
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 288
#           end_index: 343
#         }
#       }
#       confidence: 0.9300000071525574
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12195122241973877
#           y: 0.25380709767341614
#         }
#         normalized_vertices {
#           x: 0.8802167773246765
#           y: 0.25380709767341614
#         }
#         normalized_vertices {
#           x: 0.8802167773246765
#           y: 0.29487770795822144
#         }
#         normalized_vertices {
#           x: 0.12195122241973877
#           y: 0.29487770795822144
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 343
#           end_index: 354
#         }
#       }
#       confidence: 0.7699999809265137
#       bounding_poly {
#         normalized_vertices {
#           x: 0.1170731708407402
#           y: 0.30226120352745056
#         }
#         normalized_vertices {
#           x: 0.25636857748031616
#           y: 0.30226120352745056
#         }
#         normalized_vertices {
#           x: 0.25636857748031616
#           y: 0.33410245180130005
#         }
#         normalized_vertices {
#           x: 0.1170731708407402
#           y: 0.33410245180130005
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 354
#           end_index: 391
#         }
#       }
#       confidence: 0.8999999761581421
#       bounding_poly {
#         normalized_vertices {
#           x: 0.45528456568717957
#           y: 0.3017997145652771
#         }
#         normalized_vertices {
#           x: 0.9273712635040283
#           y: 0.3017997145652771
#         }
#         normalized_vertices {
#           x: 0.9273712635040283
#           y: 0.3474850058555603
#         }
#         normalized_vertices {
#           x: 0.45528456568717957
#           y: 0.3474850058555603
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 391
#           end_index: 409
#         }
#       }
#       confidence: 0.9100000262260437
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11869918555021286
#           y: 0.3507152795791626
#         }
#         normalized_vertices {
#           x: 0.3398374021053314
#           y: 0.3507152795791626
#         }
#         normalized_vertices {
#           x: 0.3398374021053314
#           y: 0.37517306208610535
#         }
#         normalized_vertices {
#           x: 0.11869918555021286
#           y: 0.37517306208610535
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 409
#           end_index: 479
#         }
#       }
#       confidence: 0.9300000071525574
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12249322235584259
#           y: 0.3839409351348877
#         }
#         normalized_vertices {
#           x: 0.9544715285301208
#           y: 0.3839409351348877
#         }
#         normalized_vertices {
#           x: 0.9544715285301208
#           y: 0.42408859729766846
#         }
#         normalized_vertices {
#           x: 0.12249322235584259
#           y: 0.42408859729766846
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 479
#           end_index: 495
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.30027100443840027
#           y: 0.3124134838581085
#         }
#         normalized_vertices {
#           x: 0.4411924183368683
#           y: 0.3124134838581085
#         }
#         normalized_vertices {
#           x: 0.4411924183368683
#           y: 0.32810336351394653
#         }
#         normalized_vertices {
#           x: 0.30027100443840027
#           y: 0.32810336351394653
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 495
#           end_index: 554
#         }
#       }
#       confidence: 0.949999988079071
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11815717816352844
#           y: 0.4420858323574066
#         }
#         normalized_vertices {
#           x: 0.7262872457504272
#           y: 0.4420858323574066
#         }
#         normalized_vertices {
#           x: 0.7262872457504272
#           y: 0.462851881980896
#         }
#         normalized_vertices {
#           x: 0.11815717816352844
#           y: 0.462851881980896
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 554
#           end_index: 592
#         }
#       }
#       confidence: 0.9200000166893005
#       bounding_poly {
#         normalized_vertices {
#           x: 0.15880759060382843
#           y: 0.4799261689186096
#         }
#         normalized_vertices {
#           x: 0.8157181739807129
#           y: 0.4799261689186096
#         }
#         normalized_vertices {
#           x: 0.8157181739807129
#           y: 0.516382098197937
#         }
#         normalized_vertices {
#           x: 0.15880759060382843
#           y: 0.516382098197937
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 592
#           end_index: 613
#         }
#       }
#       confidence: 0.9599999785423279
#       bounding_poly {
#         normalized_vertices {
#           x: 0.16856367886066437
#           y: 0.516382098197937
#         }
#         normalized_vertices {
#           x: 0.497560977935791
#           y: 0.516382098197937
#         }
#         normalized_vertices {
#           x: 0.497560977935791
#           y: 0.5639132261276245
#         }
#         normalized_vertices {
#           x: 0.16856367886066437
#           y: 0.5639132261276245
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 613
#           end_index: 681
#         }
#       }
#       confidence: 0.949999988079071
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11815717816352844
#           y: 0.7466543316841125
#         }
#         normalized_vertices {
#           x: 0.783197820186615
#           y: 0.7466543316841125
#         }
#         normalized_vertices {
#           x: 0.783197820186615
#           y: 0.7674204111099243
#         }
#         normalized_vertices {
#           x: 0.11815717816352844
#           y: 0.7674204111099243
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 681
#           end_index: 716
#         }
#       }
#       confidence: 0.9200000166893005
#       bounding_poly {
#         normalized_vertices {
#           x: 0.1642276495695114
#           y: 0.7724965214729309
#         }
#         normalized_vertices {
#           x: 0.7327913045883179
#           y: 0.7724965214729309
#         }
#         normalized_vertices {
#           x: 0.7327913045883179
#           y: 0.8283340930938721
#         }
#         normalized_vertices {
#           x: 0.1642276495695114
#           y: 0.8283340930938721
#         }
#       }
#       orientation: 1
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           end_index: 8
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11924119293689728
#           y: 0.021688971668481827
#         }
#         normalized_vertices {
#           x: 0.1902438998222351
#           y: 0.021688971668481827
#         }
#         normalized_vertices {
#           x: 0.1902438998222351
#           y: 0.03507152572274208
#         }
#         normalized_vertices {
#           x: 0.11924119293689728
#           y: 0.03507152572274208
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 8
#           end_index: 13
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.1956639587879181
#           y: 0.021688971668481827
#         }
#         normalized_vertices {
#           x: 0.23631435632705688
#           y: 0.021688971668481827
#         }
#         normalized_vertices {
#           x: 0.23631435632705688
#           y: 0.03507152572274208
#         }
#         normalized_vertices {
#           x: 0.1956639587879181
#           y: 0.03507152572274208
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 2
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 13
#           end_index: 20
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.3604336082935333
#           y: 0.044300876557826996
#         }
#         normalized_vertices {
#           x: 0.45474255084991455
#           y: 0.044300876557826996
#         }
#         normalized_vertices {
#           x: 0.45474255084991455
#           y: 0.06229810789227486
#         }
#         normalized_vertices {
#           x: 0.3604336082935333
#           y: 0.06229810789227486
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 20
#           end_index: 27
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.4710026979446411
#           y: 0.044300876557826996
#         }
#         normalized_vertices {
#           x: 0.5560975670814514
#           y: 0.044300876557826996
#         }
#         normalized_vertices {
#           x: 0.5560975670814514
#           y: 0.06229810789227486
#         }
#         normalized_vertices {
#           x: 0.4710026979446411
#           y: 0.06229810789227486
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 27
#           end_index: 32
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.5691056847572327
#           y: 0.044300876557826996
#         }
#         normalized_vertices {
#           x: 0.6352303624153137
#           y: 0.044300876557826996
#         }
#         normalized_vertices {
#           x: 0.6352303624153137
#           y: 0.06229810789227486
#         }
#         normalized_vertices {
#           x: 0.5691056847572327
#           y: 0.06229810789227486
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 2
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 32
#           end_index: 39
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12140921503305435
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.1696476936340332
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.1696476936340332
#           y: 0.09090909361839294
#         }
#         normalized_vertices {
#           x: 0.12140921503305435
#           y: 0.09090909361839294
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 39
#           end_index: 44
#         }
#       }
#       confidence: 0.9700000286102295
#       bounding_poly {
#         normalized_vertices {
#           x: 0.17940379679203033
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.19674797356128693
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.19674797356128693
#           y: 0.09090909361839294
#         }
#         normalized_vertices {
#           x: 0.17940379679203033
#           y: 0.09090909361839294
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 44
#           end_index: 48
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.20108401775360107
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.22330623865127563
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.22330623865127563
#           y: 0.09090909361839294
#         }
#         normalized_vertices {
#           x: 0.20108401775360107
#           y: 0.09090909361839294
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 48
#           end_index: 52
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.23035229742527008
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.2536585330963135
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.2536585330963135
#           y: 0.09090909361839294
#         }
#         normalized_vertices {
#           x: 0.23035229742527008
#           y: 0.09090909361839294
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 52
#           end_index: 66
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.25907859206199646
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.36097562313079834
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.36097562313079834
#           y: 0.09090909361839294
#         }
#         normalized_vertices {
#           x: 0.25907859206199646
#           y: 0.09090909361839294
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 66
#           end_index: 75
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.3685636818408966
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.4303523004055023
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.4303523004055023
#           y: 0.09090909361839294
#         }
#         normalized_vertices {
#           x: 0.3685636818408966
#           y: 0.09090909361839294
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 75
#           end_index: 77
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.431978315114975
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.437940388917923
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.437940388917923
#           y: 0.09090909361839294
#         }
#         normalized_vertices {
#           x: 0.431978315114975
#           y: 0.09090909361839294
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 77
#           end_index: 81
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.44661247730255127
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.47262871265411377
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.47262871265411377
#           y: 0.09090909361839294
#         }
#         normalized_vertices {
#           x: 0.44661247730255127
#           y: 0.09090909361839294
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 81
#           end_index: 93
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.4764227569103241
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.562601625919342
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.562601625919342
#           y: 0.09090909361839294
#         }
#         normalized_vertices {
#           x: 0.4764227569103241
#           y: 0.09090909361839294
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 93
#           end_index: 97
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.5691056847572327
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.5951219797134399
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.5951219797134399
#           y: 0.09090909361839294
#         }
#         normalized_vertices {
#           x: 0.5691056847572327
#           y: 0.09090909361839294
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 97
#           end_index: 105
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.6048780679702759
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.6612465977668762
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.6612465977668762
#           y: 0.09090909361839294
#         }
#         normalized_vertices {
#           x: 0.6048780679702759
#           y: 0.09090909361839294
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 105
#           end_index: 110
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.6634146571159363
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.6905149221420288
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.6905149221420288
#           y: 0.09090909361839294
#         }
#         normalized_vertices {
#           x: 0.6634146571159363
#           y: 0.09090909361839294
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 110
#           end_index: 113
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.6948509216308594
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.7116531133651733
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.7116531133651733
#           y: 0.09090909361839294
#         }
#         normalized_vertices {
#           x: 0.6948509216308594
#           y: 0.09090909361839294
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 113
#           end_index: 118
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7208672165870667
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.7560975551605225
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.7560975551605225
#           y: 0.09090909361839294
#         }
#         normalized_vertices {
#           x: 0.7208672165870667
#           y: 0.09090909361839294
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 118
#           end_index: 121
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7609755992889404
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.773441731929779
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.773441731929779
#           y: 0.09090909361839294
#         }
#         normalized_vertices {
#           x: 0.7609755992889404
#           y: 0.09090909361839294
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 121
#           end_index: 130
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7810298204421997
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.8504065275192261
#           y: 0.07152745872735977
#         }
#         normalized_vertices {
#           x: 0.8504065275192261
#           y: 0.09090909361839294
#         }
#         normalized_vertices {
#           x: 0.7810298204421997
#           y: 0.09090909361839294
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 2
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 130
#           end_index: 135
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12086720764636993
#           y: 0.09460083395242691
#         }
#         normalized_vertices {
#           x: 0.15555556118488312
#           y: 0.09460083395242691
#         }
#         normalized_vertices {
#           x: 0.15555556118488312
#           y: 0.11121366173028946
#         }
#         normalized_vertices {
#           x: 0.12086720764636993
#           y: 0.11121366173028946
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 135
#           end_index: 142
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.15718157589435577
#           y: 0.09413935989141464
#         }
#         normalized_vertices {
#           x: 0.2016260176897049
#           y: 0.09413935989141464
#         }
#         normalized_vertices {
#           x: 0.2016260176897049
#           y: 0.11075219511985779
#         }
#         normalized_vertices {
#           x: 0.15718157589435577
#           y: 0.11075219511985779
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 142
#           end_index: 150
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.21246612071990967
#           y: 0.09413935989141464
#         }
#         normalized_vertices {
#           x: 0.25636857748031616
#           y: 0.09413935989141464
#         }
#         normalized_vertices {
#           x: 0.25636857748031616
#           y: 0.11075219511985779
#         }
#         normalized_vertices {
#           x: 0.21246612071990967
#           y: 0.11075219511985779
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 150
#           end_index: 154
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.26449865102767944
#           y: 0.09367789328098297
#         }
#         normalized_vertices {
#           x: 0.292140930891037
#           y: 0.09367789328098297
#         }
#         normalized_vertices {
#           x: 0.292140930891037
#           y: 0.11029072105884552
#         }
#         normalized_vertices {
#           x: 0.26449865102767944
#           y: 0.11029072105884552
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#     detected_languages {
#       language_code: "en"
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 154
#           end_index: 159
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.29756098985671997
#           y: 0.09367789328098297
#         }
#         normalized_vertices {
#           x: 0.3241192400455475
#           y: 0.09367789328098297
#         }
#         normalized_vertices {
# ...
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 254
#           end_index: 260
#         }
#       }
#       confidence: 0.9977126121520996
#       bounding_poly {
#         normalized_vertices {
#           x: 0.45361894369125366
#           y: 0.22335025668144226
#         }
#         normalized_vertices {
#           x: 0.4997290074825287
#           y: 0.22335025668144226
#         }
#         normalized_vertices {
#           x: 0.4997290074825287
#           y: 0.24596215784549713
#         }
#         normalized_vertices {
#           x: 0.45361894369125366
#           y: 0.24596215784549713
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 260
#           end_index: 267
#         }
#       }
#       confidence: 0.9977126121520996
#       bounding_poly {
#         normalized_vertices {
#           x: 0.5186991691589355
#           y: 0.22335025668144226
#         }
#         normalized_vertices {
#           x: 0.6032520532608032
#           y: 0.22335025668144226
#         }
#         normalized_vertices {
#           x: 0.6032520532608032
#           y: 0.24596215784549713
#         }
#         normalized_vertices {
#           x: 0.5186991691589355
#           y: 0.24596215784549713
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 195
#           end_index: 201
#         }
#       }
#       confidence: 0.9973470568656921
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11832958459854126
#           y: 0.16935856640338898
#         }
#         normalized_vertices {
#           x: 0.19241192936897278
#           y: 0.16935856640338898
#         }
#         normalized_vertices {
#           x: 0.19241192936897278
#           y: 0.2196585088968277
#         }
#         normalized_vertices {
#           x: 0.11832958459854126
#           y: 0.2196585088968277
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 201
#           end_index: 214
#         }
#       }
#       confidence: 0.9973470568656921
#       bounding_poly {
#         normalized_vertices {
#           x: 0.23197832703590393
#           y: 0.15736040472984314
#         }
#         normalized_vertices {
#           x: 0.42222222685813904
#           y: 0.15736040472984314
#         }
#         normalized_vertices {
#           x: 0.42222222685813904
#           y: 0.2164282351732254
#         }
#         normalized_vertices {
#           x: 0.23197832703590393
#           y: 0.2164282351732254
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 267
#           end_index: 274
#         }
#       }
#       confidence: 0.9969355463981628
#       bounding_poly {
#         normalized_vertices {
#           x: 0.6397309303283691
#           y: 0.22196584939956665
#         }
#         normalized_vertices {
#           x: 0.6981030106544495
#           y: 0.22196584939956665
#         }
#         normalized_vertices {
#           x: 0.6981030106544495
#           y: 0.24550069868564606
#         }
#         normalized_vertices {
#           x: 0.6397309303283691
#           y: 0.24550069868564606
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 274
#           end_index: 277
#         }
#       }
#       confidence: 0.9969355463981628
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7062330842018127
#           y: 0.22150439023971558
#         }
#         normalized_vertices {
#           x: 0.7501354813575745
#           y: 0.22150439023971558
#         }
#         normalized_vertices {
#           x: 0.7501354813575745
#           y: 0.2450392246246338
#         }
#         normalized_vertices {
#           x: 0.7062330842018127
#           y: 0.2450392246246338
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 288
#           end_index: 295
#         }
#       }
#       confidence: 0.9962749481201172
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11840678006410599
#           y: 0.25657591223716736
#         }
#         normalized_vertices {
#           x: 0.18753387033939362
#           y: 0.25657591223716736
#         }
#         normalized_vertices {
#           x: 0.18753387033939362
#           y: 0.29487770795822144
#         }
#         normalized_vertices {
#           x: 0.11840678006410599
#           y: 0.29487770795822144
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 295
#           end_index: 325
#         }
#       }
#       confidence: 0.9962749481201172
#       bounding_poly {
#         normalized_vertices {
#           x: 0.19403794407844543
#           y: 0.25519150495529175
#         }
#         normalized_vertices {
#           x: 0.6027100086212158
#           y: 0.25519150495529175
#         }
#         normalized_vertices {
#           x: 0.6027100086212158
#           y: 0.29441624879837036
#         }
#         normalized_vertices {
#           x: 0.19403794407844543
#           y: 0.29441624879837036
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 277
#           end_index: 282
#         }
#       }
#       confidence: 0.9950175881385803
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7681438326835632
#           y: 0.22150439023971558
#         }
#         normalized_vertices {
#           x: 0.8065040707588196
#           y: 0.22150439023971558
#         }
#         normalized_vertices {
#           x: 0.8065040707588196
#           y: 0.24457775056362152
#         }
#         normalized_vertices {
#           x: 0.7681438326835632
#           y: 0.24457775056362152
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 282
#           end_index: 288
#         }
#       }
#       confidence: 0.9950175881385803
#       bounding_poly {
#         normalized_vertices {
#           x: 0.8178861737251282
#           y: 0.22058144211769104
#         }
#         normalized_vertices {
#           x: 0.8970189690589905
#           y: 0.22058144211769104
#         }
#         normalized_vertices {
#           x: 0.8970189690589905
#           y: 0.24411629140377045
#         }
#         normalized_vertices {
#           x: 0.8178861737251282
#           y: 0.24411629140377045
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 439
#           end_index: 464
#         }
#       }
#       confidence: 0.9905143976211548
#       bounding_poly {
#         normalized_vertices {
#           x: 0.48056840896606445
#           y: 0.3857868015766144
#         }
#         normalized_vertices {
#           x: 0.7501354813575745
#           y: 0.3857868015766144
#         }
#         normalized_vertices {
#           x: 0.7501354813575745
#           y: 0.42085832357406616
#         }
#         normalized_vertices {
#           x: 0.48056840896606445
#           y: 0.42085832357406616
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 464
#           end_index: 479
#         }
#       }
#       confidence: 0.9905143976211548
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7544715404510498
#           y: 0.3839409351348877
#         }
#         normalized_vertices {
#           x: 0.9544715285301208
#           y: 0.3839409351348877
#         }
#         normalized_vertices {
#           x: 0.9544715285301208
#           y: 0.4185509979724884
#         }
#         normalized_vertices {
#           x: 0.7544715404510498
#           y: 0.4185509979724884
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 613
#           end_index: 679
#         }
#       }
#       confidence: 0.9220330119132996
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11087413877248764
#           y: 0.7466543316841125
#         }
#         normalized_vertices {
#           x: 0.7761517763137817
#           y: 0.7466543316841125
#         }
#         normalized_vertices {
#           x: 0.7761517763137817
#           y: 0.7680748105049133
#         }
#         normalized_vertices {
#           x: 0.11087413877248764
#           y: 0.7680748105049133
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 617
#           end_index: 716
#         }
#       }
#       confidence: 0.9220330119132996
#       bounding_poly {
#         normalized_vertices {
#           x: 0.1642276495695114
#           y: 0.7466543316841125
#         }
#         normalized_vertices {
#           x: 0.783197820186615
#           y: 0.7466543316841125
#         }
#         normalized_vertices {
#           x: 0.783197820186615
#           y: 0.8283340930938721
#         }
#         normalized_vertices {
#           x: 0.1642276495695114
#           y: 0.8283340930938721
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 495
#           end_index: 554
#         }
#       }
#       confidence: 0.8794548511505127
#       bounding_poly {
#         normalized_vertices {
#           x: 0.10990030318498611
#           y: 0.4420858323574066
#         }
#         normalized_vertices {
#           x: 0.7262872457504272
#           y: 0.4420858323574066
#         }
#         normalized_vertices {
#           x: 0.7262872457504272
#           y: 0.462851881980896
#         }
#         normalized_vertices {
#           x: 0.10990030318498611
#           y: 0.462851881980896
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 554
#           end_index: 613
#         }
#       }
#       confidence: 0.8794548511505127
#       bounding_poly {
#         normalized_vertices {
#           x: 0.15880759060382843
#           y: 0.4799261689186096
#         }
#         normalized_vertices {
#           x: 0.8157181739807129
#           y: 0.4799261689186096
#         }
#         normalized_vertices {
#           x: 0.8157181739807129
#           y: 0.5639132261276245
#         }
#         normalized_vertices {
#           x: 0.15880759060382843
#           y: 0.5639132261276245
#         }
#       }
#       orientation: 1
#     }
#   }
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 181
#       end_index: 194
#     }
#   }
#   mention_text: "9/14/19"
#   mention_id: "0"
#   confidence: 0.9998577833175659
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 195
#       end_index: 213
#     }
#   }
#   mention_text: "Sally Walker"
#   mention_id: "1"
#   confidence: 0.9973470568656921
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 214
#       end_index: 229
#     }
#   }
#   mention_text: "09/04/1986"
#   mention_id: "2"
#   confidence: 0.9997154474258423
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 230
#       end_index: 253
#     }
#   }
#   mention_text: "24 Barney Lane"
#   mention_id: "3"
#   confidence: 0.999135434627533
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 254
#       end_index: 266
#     }
#   }
#   mention_text: "Tonaco"
#   mention_id: "4"
#   confidence: 0.9977126121520996
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 267
#       end_index: 276
#     }
#   }
#   mention_text: "NJ"
#   mention_id: "5"
#   confidence: 0.9969355463981628
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 277
#       end_index: 287
#     }
#   }
#   mention_text: "07082"
#   mention_id: "6"
#   confidence: 0.9950175881385803
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 288
#       end_index: 324
#     }
#   }
#   mention_text: "Sally, waller@cmail.com_Phone"
#   mention_id: "7"
#   confidence: 0.9962749481201172
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 325
#       end_index: 342
#     }
#   }
#   mention_text: "_(906) 917-3486"
#   mention_id: "8"
#   confidence: 0.9999823570251465
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 343
#       end_index: 353
#     }
#   }
#   mention_text: "_F"
#   mention_id: "9"
#   confidence: 0.9999330639839172
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 479
#       end_index: 495
#     }
#     text_segments {
#       start_index: 354
#       end_index: 360
#     }
#   }
#   mention_text: "Single"
#   mention_id: "10"
#   confidence: 0.9999508261680603
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 361
#       end_index: 390
#     }
#   }
#   mention_text: "Software Engineer"
#   mention_id: "11"
#   confidence: 0.9999136328697205
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 391
#       end_index: 408
#     }
#   }
#   mention_text: "None"
#   mention_id: "12"
#   confidence: 0.9998615980148315
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 409
#       end_index: 438
#     }
#   }
#   mention_text: "Eva Walker"
#   mention_id: "13"
#   confidence: 0.9999718070030212
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 439
#       end_index: 478
#     }
#   }
#   mention_text: "(906)334-89766"
#   mention_id: "14"
#   confidence: 0.9905143976211548
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 495
#       end_index: 612
#     }
#   }
#   mention_text: "Ranny nose, mucas in thoat, weakness,\naches, chills, tired"
#   mention_id: "15"
#   confidence: 0.8794548511505127
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 613
#       end_index: 679
#     }
#     text_segments {
#       start_index: 617
#       end_index: 715
#     }
#   }
#   mention_text: "you currently taking any medication? (If yes, please describe):\nVyvanse (25mg) daily for attention"
#   mention_id: "16"
#   confidence: 0.9220330119132996
# }
#
# Page number: 1
# Field Name: #:	Confidence: 0.9999823570251465
# Field Value: _(906) 917-3486
# 	Confidence: 0.9999823570251465
# Field Name: Emergency Contact: 	Confidence: 0.9999718070030212
# Field Value: Eva Walker 	Confidence: 0.9999718070030212
# Field Name: Marital Status:
# 	Confidence: 0.9999508261680603
# Field Value: Single 	Confidence: 0.9999508261680603
# Field Name: Gender: 	Confidence: 0.9999330639839172
# Field Value: _F
# 	Confidence: 0.9999330639839172
# Field Name: Occupation: 	Confidence: 0.9999136328697205
# Field Value: Software Engineer
# 	Confidence: 0.9999136328697205
# Field Name: Referred By: 	Confidence: 0.9998615980148315
# Field Value: None
# 	Confidence: 0.9998615980148315
# Field Name: Date:
# 	Confidence: 0.9998577833175659
# Field Value: 9/14/19
# 	Confidence: 0.9998577833175659
# Field Name: DOB: 	Confidence: 0.9997154474258423
# Field Value: 09/04/1986
# 	Confidence: 0.9997154474258423
# Field Name: Address: 	Confidence: 0.999135434627533
# Field Value: 24 Barney Lane 	Confidence: 0.999135434627533
# Field Name: City: 	Confidence: 0.9977126121520996
# Field Value: Tonaco 	Confidence: 0.9977126121520996
# Field Name: Name: 	Confidence: 0.9973470568656921
# Field Value: Sally Walker
# 	Confidence: 0.9973470568656921
# Field Name: State: 	Confidence: 0.9969355463981628
# Field Value: NJ 	Confidence: 0.9969355463981628
# Field Name: Email: 	Confidence: 0.9962749481201172
# Field Value: Sally, waller@cmail.com_Phone 	Confidence: 0.9962749481201172
# Field Name: Zip: 	Confidence: 0.9950175881385803
# Field Value: 07082
# 	Confidence: 0.9950175881385803
# Field Name: Emergency Contact Phone: 	Confidence: 0.9905143976211548
# Field Value: (906)334-89766
# 	Confidence: 0.9905143976211548
# Field Name: Are you currently taking any medication? (If yes, please describe)	Confidence: 0.9220330119132996
# Field Value: you currently taking any medication? (If yes, please describe):
# Vyvanse (25mg) daily for attention
# 	Confidence: 0.9220330119132996
# Field Name: Describe your medical concerns (symptoms, diagnoses, etc):
# 	Confidence: 0.8794548511505127
# Field Value: Ranny nose, mucas in thoat, weakness,
# aches, chills, tired
# 	Confidence: 0.8794548511505127

# %% [markdown]
# ** Output **
#
# Response contains:
#
# - document text
#
# and vertices of :
#
#
# - pages in document
#
#     - blocks in each page
#
#         - paragrahs in each block
#
#             - lines in each paragraph
#
#                 - tokens in each line
#
#     - formfields in each page
#
#         - it contains:
#
#             - start and end index of fieldnames
#
#             - start and end index of fieldvalues
#
# Doc AI identifies form fields by their offsets in document text. We converts this offsets to text snippets.

# %% [markdown]
# ### Parsing gif images

# %% [markdown]
# For Parsing gif images: mime type used is image/gif

# %%
def parse_form_gif(project_id,
               input_uri):
    """Parse a form"""

    client = documentai.DocumentUnderstandingServiceClient()

    gcs_source = documentai.types.GcsSource(uri=input_uri)

    # mime_type can be application/pdf, image/tiff,
    # and image/gif, or application/json
    input_config = documentai.types.InputConfig(
        gcs_source=gcs_source, mime_type='image/gif')

    # Setting enabled=True enables form extraction
    form_extraction_params = documentai.types.FormExtractionParams(
        enabled=True)

    # Location can be 'us' or 'eu'
    parent = 'projects/{}/locations/us'.format(project_id)
    request = documentai.types.ProcessDocumentRequest(
        parent=parent,
        input_config=input_config,
        form_extraction_params=form_extraction_params)

    document = client.process_document(request=request)
    print('document: \n',document)
    
    def _get_text(el):
        """Doc AI identifies form fields by their offsets
        in document text. This function converts offsets
        to text snippets.
        """
        response = ''
        # If a text segment spans several lines, it will
        # be stored in different text segments.
        for segment in el.text_anchor.text_segments:
            start_index = segment.start_index
            end_index = segment.end_index
            response += document.text[start_index:end_index]
        return response

    for page in document.pages:
        print('Page number: {}'.format(page.page_number))
        for form_field in page.form_fields:
            print('Field Name: {}\tConfidence: {}'.format(
                _get_text(form_field.field_name),
                form_field.field_name.confidence))
            print('Field Value: {}\tConfidence: {}'.format(
                _get_text(form_field.field_value),
                form_field.field_value.confidence))

# %%
# calling above function

parse_form_gif("project-001-285307","gs://bucket0406/loan_form.gif")
# Out:
# document:
#  mime_type: "image/gif"
# text: "Loan Agreement Form\nAgreement Number:\n0123456789\nAgreement date:\n01/01/2020\nThis loan agreement is commenced between the parties:\nMortgage company contact details:\nName:\nMortgage company A\nAddress:\n100 Franklin Street, Mountain View, CA, 94035\nPhone number: 1-800-843-8623\n(hereinafter referred to as the lender)\nIndividual details:\nName:\nArjun Patel\nMarital status:\nSingle ,\nMarried O\nOther D\nAddress:\n500 Castro Street, Mountain View, CA 94035\nPhone number: 650-987-0934\n(hereinafter referred to as the borrower)\n[Fill in all details as per instructions]\nThe lender is ready to sanction $\n2000\nas the loan amount at\n6.0\n%.\n[Total loan amount along with the agreed percentage rate).\nThis loan agreement is valid from 01/01/2020 and is ending on 12/31/2020.\nTerms & agreements:\n38.67\nper month for\n5\nyears.\nThe borrower will pay an installment of $\n[Amount & tenure of loan]\nAny late installment will be accepted with $\n40\nas a fine.\n"
# pages {
#   page_number: 1
#   dimension {
#     width: 2550.0
#     height: 3300.0
#     unit: "pixels"
#   }
#   layout {
#     text_anchor {
#       text_segments {
#         end_index: 934
#       }
#     }
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 2550
#       }
#       vertices {
#         x: 2550
#         y: 3300
#       }
#       vertices {
#         y: 3300
#       }
#       normalized_vertices {
#       }
#       normalized_vertices {
#         x: 1.0
#       }
#       normalized_vertices {
#         x: 1.0
#         y: 1.0
#       }
#       normalized_vertices {
#         y: 1.0
#       }
#     }
#     orientation: 1
#   }
#   detected_languages {
#     language_code: "en"
#     confidence: 0.949999988079071
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           end_index: 20
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.33725491166114807
#           y: 0.04363636299967766
#         }
#         normalized_vertices {
#           x: 0.6509804129600525
#           y: 0.04363636299967766
#         }
#         normalized_vertices {
#           x: 0.6509804129600525
#           y: 0.07242424041032791
#         }
#         normalized_vertices {
#           x: 0.33725491166114807
#           y: 0.07242424041032791
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 20
#           end_index: 38
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.1286274492740631
#           y: 0.11696969717741013
#         }
#         normalized_vertices {
#           x: 0.295686274766922
#           y: 0.11515151709318161
#         }
#         normalized_vertices {
#           x: 0.2960784435272217
#           y: 0.12969696521759033
#         }
#         normalized_vertices {
#           x: 0.1290196031332016
#           y: 0.13151514530181885
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 38
#           end_index: 49
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.31333333253860474
#           y: 0.11818181723356247
#         }
#         normalized_vertices {
#           x: 0.41019606590270996
#           y: 0.11818181723356247
#         }
#         normalized_vertices {
#           x: 0.41019606590270996
#           y: 0.12939393520355225
#         }
#         normalized_vertices {
#           x: 0.31333333253860474
#           y: 0.12939393520355225
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 49
#           end_index: 65
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12784314155578613
#           y: 0.16575758159160614
#         }
#         normalized_vertices {
#           x: 0.2666666805744171
#           y: 0.16393938660621643
#         }
#         normalized_vertices {
#           x: 0.2670588195323944
#           y: 0.17909090220928192
#         }
#         normalized_vertices {
#           x: 0.12823529541492462
#           y: 0.18090909719467163
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 65
#           end_index: 76
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.2925490140914917
#           y: 0.1666666716337204
#         }
#         normalized_vertices {
#           x: 0.37921568751335144
#           y: 0.1666666716337204
#         }
#         normalized_vertices {
#           x: 0.37921568751335144
#           y: 0.17848484218120575
#         }
#         normalized_vertices {
#           x: 0.2925490140914917
#           y: 0.17848484218120575
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 76
#           end_index: 164
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11725490540266037
#           y: 0.20787878334522247
#         }
#         normalized_vertices {
#           x: 0.746666669845581
#           y: 0.20787878334522247
#         }
#         normalized_vertices {
#           x: 0.746666669845581
#           y: 0.24030302464962006
#         }
#         normalized_vertices {
#           x: 0.11725490540266037
#           y: 0.24030302464962006
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 164
#           end_index: 170
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12627451121807098
#           y: 0.2669697105884552
#         }
#         normalized_vertices {
#           x: 0.18000000715255737
#           y: 0.2669697105884552
#         }
#         normalized_vertices {
#           x: 0.18000000715255737
#           y: 0.27848485112190247
#         }
#         normalized_vertices {
#           x: 0.12627451121807098
#           y: 0.27848485112190247
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 170
#           end_index: 189
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.22274509072303772
#           y: 0.26757577061653137
#         }
#         normalized_vertices {
#           x: 0.3964705765247345
#           y: 0.26757577061653137
#         }
#         normalized_vertices {
#           x: 0.3964705765247345
#           y: 0.2821212112903595
#         }
#         normalized_vertices {
#           x: 0.22274509072303772
#           y: 0.2821212112903595
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 189
#           end_index: 198
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.125490203499794
#           y: 0.31515151262283325
#         }
#         normalized_vertices {
#           x: 0.19882352650165558
#           y: 0.31515151262283325
#         }
#         normalized_vertices {
#           x: 0.19882352650165558
#           y: 0.3275757431983948
#         }
#         normalized_vertices {
#           x: 0.125490203499794
#           y: 0.3275757431983948
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 198
#           end_index: 244
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.2262745052576065
#           y: 0.3160606026649475
#         }
#         normalized_vertices {
#           x: 0.5945097804069519
#           y: 0.3160606026649475
#         }
#         normalized_vertices {
#           x: 0.5945097804069519
#           y: 0.32969698309898376
#         }
#         normalized_vertices {
#           x: 0.2262745052576065
#           y: 0.32969698309898376
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 244
#           end_index: 273
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12705881893634796
#           y: 0.36454546451568604
#         }
#         normalized_vertices {
#           x: 0.4000000059604645
#           y: 0.36636364459991455
#         }
#         normalized_vertices {
#           x: 0.4000000059604645
#           y: 0.37939393520355225
#         }
#         normalized_vertices {
#           x: 0.12705881893634796
#           y: 0.37757575511932373
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 273
#           end_index: 313
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.1196078434586525
#           y: 0.38969695568084717
#         }
#         normalized_vertices {
#           x: 0.42274510860443115
#           y: 0.38969695568084717
#         }
#         normalized_vertices {
#           x: 0.42274510860443115
#           y: 0.40272727608680725
#         }
#         normalized_vertices {
#           x: 0.1196078434586525
#           y: 0.40272727608680725
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 313
#           end_index: 333
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11921568959951401
#           y: 0.42363637685775757
#         }
#         normalized_vertices {
#           x: 0.2572548985481262
#           y: 0.42363637685775757
#         }
#         normalized_vertices {
#           x: 0.2572548985481262
#           y: 0.4360606074333191
#         }
#         normalized_vertices {
#           x: 0.11921568959951401
#           y: 0.4360606074333191
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 333
#           end_index: 339
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12431372702121735
#           y: 0.4654545485973358
#         }
#         normalized_vertices {
#           x: 0.1796078383922577
#           y: 0.4654545485973358
#         }
#         normalized_vertices {
#           x: 0.1796078383922577
#           y: 0.476666659116745
#         }
#         normalized_vertices {
#           x: 0.12431372702121735
#           y: 0.476666659116745
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 339
#           end_index: 351
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.22509804368019104
#           y: 0.4663636386394501
#         }
#         normalized_vertices {
#           x: 0.3121568560600281
#           y: 0.46424242854118347
#         }
#         normalized_vertices {
#           x: 0.31254902482032776
#           y: 0.4790908992290497
#         }
#         normalized_vertices {
#           x: 0.22588235139846802
#           y: 0.4812121093273163
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 351
#           end_index: 367
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.4184313714504242
#           y: 0.46424242854118347
#         }
#         normalized_vertices {
#           x: 0.5360784530639648
#           y: 0.4663636386394501
#         }
#         normalized_vertices {
#           x: 0.5356862545013428
#           y: 0.47787877917289734
#         }
#         normalized_vertices {
#           x: 0.4180392026901245
#           y: 0.47575756907463074
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 367
#           end_index: 376
#         }
#       }
#       confidence: 0.8799999952316284
#       bounding_poly {
#         normalized_vertices {
#           x: 0.5666666626930237
#           y: 0.4657575786113739
#         }
#         normalized_vertices {
#           x: 0.6376470327377319
#           y: 0.46424242854118347
#         }
#         normalized_vertices {
#           x: 0.638039231300354
#           y: 0.4812121093273163
#         }
#         normalized_vertices {
#           x: 0.567451000213623
#           y: 0.4827272593975067
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 376
#           end_index: 386
#         }
#       }
#       confidence: 0.9200000166893005
#       bounding_poly {
#         normalized_vertices {
#           x: 0.6654902100563049
#           y: 0.466060608625412
#         }
#         normalized_vertices {
#           x: 0.7494117617607117
#           y: 0.4663636386394501
#         }
#         normalized_vertices {
#           x: 0.7494117617607117
#           y: 0.4787878692150116
#         }
#         normalized_vertices {
#           x: 0.6654902100563049
#           y: 0.4784848392009735
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 386
#           end_index: 394
#         }
#       }
#       confidence: 0.8600000143051147
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7862744927406311
#           y: 0.4663636386394501
#         }
#         normalized_vertices {
#           x: 0.8552941083908081
#           y: 0.4663636386394501
#         }
#         normalized_vertices {
#           x: 0.8552941083908081
#           y: 0.4790908992290497
#         }
#         normalized_vertices {
#           x: 0.7862744927406311
#           y: 0.4790908992290497
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 394
#           end_index: 403
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12627451121807098
#           y: 0.5151515007019043
#         }
#         normalized_vertices {
#           x: 0.19960784912109375
#           y: 0.5163636207580566
#         }
#         normalized_vertices {
#           x: 0.19921568036079407
#           y: 0.5290908813476562
#         }
#         normalized_vertices {
#           x: 0.1258823573589325
#           y: 0.5278787612915039
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 403
#           end_index: 446
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.22235293686389923
#           y: 0.5157575607299805
#         }
#         normalized_vertices {
#           x: 0.5843137502670288
#           y: 0.5157575607299805
#         }
#         normalized_vertices {
#           x: 0.5843137502670288
#           y: 0.528181791305542
#         }
#         normalized_vertices {
#           x: 0.22235293686389923
#           y: 0.528181791305542
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 446
#           end_index: 473
#         }
#       }
#       confidence: 0.9700000286102295
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12705881893634796
#           y: 0.564242422580719
#         }
#         normalized_vertices {
#           x: 0.38509804010391235
#           y: 0.5660606026649475
#         }
#         normalized_vertices {
#           x: 0.38509804010391235
#           y: 0.5787878632545471
#         }
#         normalized_vertices {
#           x: 0.12705881893634796
#           y: 0.5769696831703186
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 473
#           end_index: 515
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12039215862751007
#           y: 0.5893939137458801
#         }
#         normalized_vertices {
#           x: 0.4494117498397827
#           y: 0.5893939137458801
#         }
#         normalized_vertices {
#           x: 0.4494117498397827
#           y: 0.6036363840103149
#         }
#         normalized_vertices {
#           x: 0.12039215862751007
#           y: 0.6036363840103149
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 515
#           end_index: 557
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11882352828979492
#           y: 0.6230303049087524
#         }
#         normalized_vertices {
#           x: 0.40156862139701843
#           y: 0.6239393949508667
#         }
#         normalized_vertices {
#           x: 0.40156862139701843
#           y: 0.6396969556808472
#         }
#         normalized_vertices {
#           x: 0.11882352828979492
#           y: 0.6387878656387329
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 557
#           end_index: 591
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11921568959951401
#           y: 0.6642424464225769
#         }
#         normalized_vertices {
#           x: 0.3780392110347748
#           y: 0.6642424464225769
#         }
#         normalized_vertices {
#           x: 0.3780392110347748
#           y: 0.6784848570823669
#         }
#         normalized_vertices {
#           x: 0.11921568959951401
#           y: 0.6784848570823669
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 591
#           end_index: 596
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.40666666626930237
#           y: 0.6669697165489197
#         }
#         normalized_vertices {
#           x: 0.4462745189666748
#           y: 0.6669697165489197
#         }
#         normalized_vertices {
#           x: 0.4462745189666748
#           y: 0.6778787970542908
#         }
#         normalized_vertices {
#           x: 0.40666666626930237
#           y: 0.6778787970542908
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 596
#           end_index: 618
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.5047059059143066
#           y: 0.6654545664787292
#         }
#         normalized_vertices {
#           x: 0.6800000071525574
#           y: 0.6648485064506531
#         }
#         normalized_vertices {
#           x: 0.6800000071525574
#           y: 0.6769697070121765
#         }
#         normalized_vertices {
#           x: 0.5047059059143066
#           y: 0.6775757670402527
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 618
#           end_index: 622
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7019608020782471
#           y: 0.6663636565208435
#         }
#         normalized_vertices {
#           x: 0.7239215970039368
#           y: 0.6663636565208435
#         }
#         normalized_vertices {
#           x: 0.7239215970039368
#           y: 0.6772727370262146
#         }
#         normalized_vertices {
#           x: 0.7019608020782471
#           y: 0.6772727370262146
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 622
#           end_index: 625
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.791372537612915
#           y: 0.6654545664787292
#         }
#         normalized_vertices {
#           x: 0.8050980567932129
#           y: 0.6657575964927673
#         }
#         normalized_vertices {
#           x: 0.8047058582305908
#           y: 0.6766666769981384
#         }
#         normalized_vertices {
#           x: 0.7909803986549377
#           y: 0.6763636469841003
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 625
#           end_index: 684
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.1227450966835022
#           y: 0.6890909075737
#         }
#         normalized_vertices {
#           x: 0.6027451157569885
#           y: 0.6890909075737
#         }
#         normalized_vertices {
#           x: 0.6027451157569885
#           y: 0.7060605883598328
#         }
#         normalized_vertices {
#           x: 0.1227450966835022
#           y: 0.7060605883598328
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 684
#           end_index: 758
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12078431248664856
#           y: 0.7239394187927246
#         }
#         normalized_vertices {
#           x: 0.7113725543022156
#           y: 0.7239394187927246
#         }
#         normalized_vertices {
#           x: 0.7113725543022156
#           y: 0.7396969795227051
#         }
#         normalized_vertices {
#           x: 0.12078431248664856
#           y: 0.7396969795227051
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 758
#           end_index: 778
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12039215862751007
#           y: 0.7581818103790283
#         }
#         normalized_vertices {
#           x: 0.30352941155433655
#           y: 0.7596969604492188
#         }
#         normalized_vertices {
#           x: 0.30313724279403687
#           y: 0.774545431137085
#         }
#         normalized_vertices {
#           x: 0.11999999731779099
#           y: 0.7730302810668945
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 778
#           end_index: 784
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.474117636680603
#           y: 0.8009091019630432
#         }
#         normalized_vertices {
#           x: 0.5129411816596985
#           y: 0.8012121319770813
#         }
#         normalized_vertices {
#           x: 0.5125490427017212
#           y: 0.8124242424964905
#         }
#         normalized_vertices {
#           x: 0.474117636680603
#           y: 0.8121212124824524
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 784
#           end_index: 798
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.5615686178207397
#           y: 0.8006060719490051
#         }
#         normalized_vertices {
#           x: 0.6760784387588501
#           y: 0.7975757718086243
#         }
#         normalized_vertices {
#           x: 0.6764705777168274
#           y: 0.8115151524543762
#         }
#         normalized_vertices {
#           x: 0.5623529553413391
#           y: 0.8145454525947571
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 798
#           end_index: 800
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7023529410362244
#           y: 0.800000011920929
#         }
#         normalized_vertices {
#           x: 0.7058823704719543
#           y: 0.800000011920929
#         }
#         normalized_vertices {
#           x: 0.7058823704719543
#           y: 0.8100000023841858
#         }
#         normalized_vertices {
#           x: 0.7023529410362244
#           y: 0.8100000023841858
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 800
#           end_index: 807
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.8145098090171814
#           y: 0.8021212220191956
#         }
#         normalized_vertices {
#           x: 0.8635293841362
#           y: 0.8021212220191956
#         }
#         normalized_vertices {
#           x: 0.8635293841362
#           y: 0.8145454525947571
#         }
#         normalized_vertices {
#           x: 0.8145098090171814
#           y: 0.8145454525947571
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 807
#           end_index: 875
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11882352828979492
#           y: 0.7987878918647766
#         }
#         normalized_vertices {
#           x: 0.4427450895309448
#           y: 0.7987878918647766
#         }
#         normalized_vertices {
#           x: 0.4427450895309448
#           y: 0.838787853717804
#         }
#         normalized_vertices {
#           x: 0.11882352828979492
#           y: 0.838787853717804
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 875
#           end_index: 920
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12392156571149826
#           y: 0.8651515245437622
#         }
#         normalized_vertices {
#           x: 0.4678431451320648
#           y: 0.8651515245437622
#         }
#         normalized_vertices {
#           x: 0.4678431451320648
#           y: 0.8809090852737427
#         }
#         normalized_vertices {
#           x: 0.12392156571149826
#           y: 0.8809090852737427
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 920
#           end_index: 923
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.4941176474094391
#           y: 0.8672727346420288
#         }
#         normalized_vertices {
#           x: 0.5137255191802979
#           y: 0.8672727346420288
#         }
#         normalized_vertices {
#           x: 0.5137255191802979
#           y: 0.8772727251052856
#         }
#         normalized_vertices {
#           x: 0.4941176474094391
#           y: 0.8772727251052856
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 923
#           end_index: 934
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7960784435272217
#           y: 0.8663636445999146
#         }
#         normalized_vertices {
#           x: 0.8662745356559753
#           y: 0.864545464515686
#         }
#         normalized_vertices {
#           x: 0.8666666746139526
#           y: 0.8760606050491333
#         }
#         normalized_vertices {
#           x: 0.796470582485199
#           y: 0.8778787851333618
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           end_index: 20
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.33725491166114807
#           y: 0.04363636299967766
#         }
#         normalized_vertices {
#           x: 0.6509804129600525
#           y: 0.04363636299967766
#         }
#         normalized_vertices {
#           x: 0.6509804129600525
#           y: 0.07242424041032791
#         }
#         normalized_vertices {
#           x: 0.33725491166114807
#           y: 0.07242424041032791
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 20
#           end_index: 38
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.1286274492740631
#           y: 0.11696969717741013
#         }
#         normalized_vertices {
#           x: 0.295686274766922
#           y: 0.11515151709318161
#         }
#         normalized_vertices {
#           x: 0.2960784435272217
#           y: 0.12969696521759033
#         }
#         normalized_vertices {
#           x: 0.1290196031332016
#           y: 0.13151514530181885
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 38
#           end_index: 49
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.31333333253860474
#           y: 0.11818181723356247
#         }
#         normalized_vertices {
#           x: 0.41019606590270996
#           y: 0.11818181723356247
#         }
#         normalized_vertices {
#           x: 0.41019606590270996
#           y: 0.12939393520355225
#         }
#         normalized_vertices {
#           x: 0.31333333253860474
#           y: 0.12939393520355225
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 49
#           end_index: 65
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12784314155578613
#           y: 0.16575758159160614
#         }
#         normalized_vertices {
#           x: 0.2666666805744171
#           y: 0.16393938660621643
#         }
#         normalized_vertices {
#           x: 0.2670588195323944
#           y: 0.17909090220928192
#         }
#         normalized_vertices {
#           x: 0.12823529541492462
#           y: 0.18090909719467163
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 65
#           end_index: 76
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.2925490140914917
#           y: 0.1666666716337204
#         }
#         normalized_vertices {
#           x: 0.37921568751335144
#           y: 0.1666666716337204
#         }
#         normalized_vertices {
#           x: 0.37921568751335144
#           y: 0.17848484218120575
#         }
#         normalized_vertices {
#           x: 0.2925490140914917
#           y: 0.17848484218120575
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 76
#           end_index: 164
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11725490540266037
#           y: 0.20787878334522247
#         }
#         normalized_vertices {
#           x: 0.746666669845581
#           y: 0.20787878334522247
#         }
#         normalized_vertices {
#           x: 0.746666669845581
#           y: 0.24030302464962006
#         }
#         normalized_vertices {
#           x: 0.11725490540266037
#           y: 0.24030302464962006
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 164
#           end_index: 170
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12627451121807098
#           y: 0.2669697105884552
#         }
#         normalized_vertices {
#           x: 0.18000000715255737
#           y: 0.2669697105884552
#         }
#         normalized_vertices {
#           x: 0.18000000715255737
#           y: 0.27848485112190247
#         }
#         normalized_vertices {
#           x: 0.12627451121807098
#           y: 0.27848485112190247
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 170
#           end_index: 189
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.22274509072303772
#           y: 0.26757577061653137
#         }
#         normalized_vertices {
#           x: 0.3964705765247345
#           y: 0.26757577061653137
#         }
#         normalized_vertices {
#           x: 0.3964705765247345
#           y: 0.2821212112903595
#         }
#         normalized_vertices {
#           x: 0.22274509072303772
#           y: 0.2821212112903595
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 189
#           end_index: 198
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.125490203499794
#           y: 0.31515151262283325
#         }
#         normalized_vertices {
#           x: 0.19882352650165558
#           y: 0.31515151262283325
#         }
#         normalized_vertices {
#           x: 0.19882352650165558
#           y: 0.3275757431983948
#         }
#         normalized_vertices {
#           x: 0.125490203499794
#           y: 0.3275757431983948
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 198
#           end_index: 244
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.2262745052576065
#           y: 0.3160606026649475
#         }
#         normalized_vertices {
#           x: 0.5945097804069519
#           y: 0.3160606026649475
#         }
#         normalized_vertices {
#           x: 0.5945097804069519
#           y: 0.32969698309898376
#         }
#         normalized_vertices {
#           x: 0.2262745052576065
#           y: 0.32969698309898376
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 244
#           end_index: 273
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12705881893634796
#           y: 0.36454546451568604
#         }
#         normalized_vertices {
#           x: 0.4000000059604645
#           y: 0.36636364459991455
#         }
#         normalized_vertices {
#           x: 0.4000000059604645
#           y: 0.37939393520355225
#         }
#         normalized_vertices {
#           x: 0.12705881893634796
#           y: 0.37757575511932373
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 273
#           end_index: 313
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.1196078434586525
#           y: 0.38969695568084717
#         }
#         normalized_vertices {
#           x: 0.42274510860443115
#           y: 0.38969695568084717
#         }
#         normalized_vertices {
#           x: 0.42274510860443115
#           y: 0.40272727608680725
#         }
#         normalized_vertices {
#           x: 0.1196078434586525
#           y: 0.40272727608680725
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 313
#           end_index: 333
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11921568959951401
#           y: 0.42363637685775757
#         }
#         normalized_vertices {
#           x: 0.2572548985481262
#           y: 0.42363637685775757
#         }
#         normalized_vertices {
#           x: 0.2572548985481262
#           y: 0.4360606074333191
#         }
#         normalized_vertices {
#           x: 0.11921568959951401
#           y: 0.4360606074333191
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 333
#           end_index: 339
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12431372702121735
#           y: 0.4654545485973358
#         }
#         normalized_vertices {
#           x: 0.1796078383922577
#           y: 0.4654545485973358
#         }
#         normalized_vertices {
#           x: 0.1796078383922577
#           y: 0.476666659116745
#         }
#         normalized_vertices {
#           x: 0.12431372702121735
#           y: 0.476666659116745
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 339
#           end_index: 351
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.22509804368019104
#           y: 0.4663636386394501
#         }
#         normalized_vertices {
#           x: 0.3121568560600281
#           y: 0.46424242854118347
#         }
#         normalized_vertices {
#           x: 0.31254902482032776
#           y: 0.4790908992290497
#         }
#         normalized_vertices {
#           x: 0.22588235139846802
#           y: 0.4812121093273163
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 351
#           end_index: 367
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.4184313714504242
#           y: 0.46424242854118347
#         }
#         normalized_vertices {
#           x: 0.5360784530639648
#           y: 0.4663636386394501
#         }
#         normalized_vertices {
#           x: 0.5356862545013428
#           y: 0.47787877917289734
#         }
#         normalized_vertices {
#           x: 0.4180392026901245
#           y: 0.47575756907463074
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 367
#           end_index: 376
#         }
#       }
#       confidence: 0.8799999952316284
#       bounding_poly {
#         normalized_vertices {
#           x: 0.5666666626930237
#           y: 0.4657575786113739
#         }
#         normalized_vertices {
#           x: 0.6376470327377319
#           y: 0.46424242854118347
#         }
#         normalized_vertices {
#           x: 0.638039231300354
#           y: 0.4812121093273163
#         }
#         normalized_vertices {
#           x: 0.567451000213623
#           y: 0.4827272593975067
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 376
#           end_index: 386
#         }
#       }
#       confidence: 0.9200000166893005
#       bounding_poly {
#         normalized_vertices {
#           x: 0.6654902100563049
#           y: 0.466060608625412
#         }
#         normalized_vertices {
#           x: 0.7494117617607117
#           y: 0.4663636386394501
#         }
#         normalized_vertices {
#           x: 0.7494117617607117
#           y: 0.4787878692150116
#         }
#         normalized_vertices {
#           x: 0.6654902100563049
#           y: 0.4784848392009735
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 386
#           end_index: 394
#         }
#       }
#       confidence: 0.8600000143051147
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7862744927406311
#           y: 0.4663636386394501
#         }
#         normalized_vertices {
#           x: 0.8552941083908081
#           y: 0.4663636386394501
#         }
#         normalized_vertices {
#           x: 0.8552941083908081
#           y: 0.4790908992290497
#         }
#         normalized_vertices {
#           x: 0.7862744927406311
#           y: 0.4790908992290497
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 394
#           end_index: 403
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12627451121807098
#           y: 0.5151515007019043
#         }
#         normalized_vertices {
#           x: 0.19960784912109375
#           y: 0.5163636207580566
#         }
#         normalized_vertices {
#           x: 0.19921568036079407
#           y: 0.5290908813476562
#         }
#         normalized_vertices {
#           x: 0.1258823573589325
#           y: 0.5278787612915039
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 403
#           end_index: 446
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.22235293686389923
#           y: 0.5157575607299805
#         }
#         normalized_vertices {
#           x: 0.5843137502670288
#           y: 0.5157575607299805
#         }
#         normalized_vertices {
#           x: 0.5843137502670288
#           y: 0.528181791305542
#         }
#         normalized_vertices {
#           x: 0.22235293686389923
#           y: 0.528181791305542
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 446
#           end_index: 473
#         }
#       }
#       confidence: 0.9700000286102295
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12705881893634796
#           y: 0.564242422580719
#         }
#         normalized_vertices {
#           x: 0.38509804010391235
#           y: 0.5660606026649475
#         }
#         normalized_vertices {
#           x: 0.38509804010391235
#           y: 0.5787878632545471
#         }
#         normalized_vertices {
#           x: 0.12705881893634796
#           y: 0.5769696831703186
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 473
#           end_index: 515
#         }
#       }
#       confidence: 0.9900000095367432
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12039215862751007
#           y: 0.5893939137458801
#         }
#         normalized_vertices {
#           x: 0.4494117498397827
#           y: 0.5893939137458801
#         }
#         normalized_vertices {
#           x: 0.4494117498397827
#           y: 0.6036363840103149
#         }
#         normalized_vertices {
#           x: 0.12039215862751007
#           y: 0.6036363840103149
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 515
#           end_index: 557
#         }
#       }
#       confidence: 0.9800000190734863
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11882352828979492
#           y: 0.6230303049087524
#         }
#         normalized_vertices {
#           x: 0.40156862139701843
#           y: 0.6239393949508667
#         }
#         normalized_vertices {
#           x: 0.40156862139701843
#           y: 0.6396969556808472
#         }
#         normalized_vertices {
#           x: 0.11882352828979492
#           y: 0.6387878656387329
#         }
#       }
#       orientation: 1
#     }
#     detected_languages {
#       language_code: "en"
#       confidence: 1.0
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 557
#           end_index: 591
# ...
#       bounding_poly {
#         normalized_vertices {
#           x: 0.6268277764320374
#           y: 0.46454545855522156
#         }
#         normalized_vertices {
#           x: 0.6415650844573975
#           y: 0.46454545855522156
#         }
#         normalized_vertices {
#           x: 0.6415650844573975
#           y: 0.4812121093273163
#         }
#         normalized_vertices {
#           x: 0.6268277764320374
#           y: 0.4812121093273163
#         }
#       }
#       orientation: 1
#     }
#     value_type: "filled_checkbox"
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 784
#           end_index: 798
#         }
#       }
#       confidence: 0.9999465346336365
#       bounding_poly {
#         normalized_vertices {
#           x: 0.5615686178207397
#           y: 0.7975757718086243
#         }
#         normalized_vertices {
#           x: 0.6773050427436829
#           y: 0.7975757718086243
#         }
#         normalized_vertices {
#           x: 0.6773050427436829
#           y: 0.8139393925666809
#         }
#         normalized_vertices {
#           x: 0.5615686178207397
#           y: 0.8139393925666809
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 798
#           end_index: 805
#         }
#       }
#       confidence: 0.9999465346336365
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7023529410362244
#           y: 0.800000011920929
#         }
#         normalized_vertices {
#           x: 0.8556862473487854
#           y: 0.800000011920929
#         }
#         normalized_vertices {
#           x: 0.8556862473487854
#           y: 0.8145454525947571
#         }
#         normalized_vertices {
#           x: 0.7023529410362244
#           y: 0.8145454525947571
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 807
#           end_index: 849
#         }
#       }
#       confidence: 0.9998992681503296
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12137831747531891
#           y: 0.7987878918647766
#         }
#         normalized_vertices {
#           x: 0.44350844621658325
#           y: 0.7987878918647766
#         }
#         normalized_vertices {
#           x: 0.44350844621658325
#           y: 0.8139393925666809
#         }
#         normalized_vertices {
#           x: 0.12137831747531891
#           y: 0.8139393925666809
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 778
#           end_index: 784
#         }
#       }
#       confidence: 0.9998992681503296
#       bounding_poly {
#         normalized_vertices {
#           x: 0.474117636680603
#           y: 0.8009091019630432
#         }
#         normalized_vertices {
#           x: 0.5129411816596985
#           y: 0.8009091019630432
#         }
#         normalized_vertices {
#           x: 0.5129411816596985
#           y: 0.8124242424964905
#         }
#         normalized_vertices {
#           x: 0.474117636680603
#           y: 0.8124242424964905
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 557
#           end_index: 591
#         }
#       }
#       confidence: 0.9994090795516968
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11859355121850967
#           y: 0.6642424464225769
#         }
#         normalized_vertices {
#           x: 0.3780392110347748
#           y: 0.6642424464225769
#         }
#         normalized_vertices {
#           x: 0.3780392110347748
#           y: 0.6790964007377625
#         }
#         normalized_vertices {
#           x: 0.11859355121850967
#           y: 0.6790964007377625
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 591
#           end_index: 596
#         }
#       }
#       confidence: 0.9994090795516968
#       bounding_poly {
#         normalized_vertices {
#           x: 0.40666666626930237
#           y: 0.6669697165489197
#         }
#         normalized_vertices {
#           x: 0.4462745189666748
#           y: 0.6669697165489197
#         }
#         normalized_vertices {
#           x: 0.4462745189666748
#           y: 0.6778787970542908
#         }
#         normalized_vertices {
#           x: 0.40666666626930237
#           y: 0.6778787970542908
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 596
#           end_index: 618
#         }
#       }
#       confidence: 0.9930983185768127
#       bounding_poly {
#         normalized_vertices {
#           x: 0.5047059059143066
#           y: 0.6648485064506531
#         }
#         normalized_vertices {
#           x: 0.6800000071525574
#           y: 0.6648485064506531
#         }
#         normalized_vertices {
#           x: 0.6800000071525574
#           y: 0.6772727370262146
#         }
#         normalized_vertices {
#           x: 0.5047059059143066
#           y: 0.6772727370262146
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 618
#           end_index: 622
#         }
#       }
#       confidence: 0.9930983185768127
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7019608020782471
#           y: 0.6663636565208435
#         }
#         normalized_vertices {
#           x: 0.7239215970039368
#           y: 0.6663636565208435
#         }
#         normalized_vertices {
#           x: 0.7239215970039368
#           y: 0.6772727370262146
#         }
#         normalized_vertices {
#           x: 0.7019608020782471
#           y: 0.6772727370262146
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 164
#           end_index: 170
#         }
#       }
#       confidence: 0.9908154606819153
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12627451121807098
#           y: 0.2669697105884552
#         }
#         normalized_vertices {
#           x: 0.18000000715255737
#           y: 0.2669697105884552
#         }
#         normalized_vertices {
#           x: 0.18000000715255737
#           y: 0.27848485112190247
#         }
#         normalized_vertices {
#           x: 0.12627451121807098
#           y: 0.27848485112190247
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 170
#           end_index: 189
#         }
#       }
#       confidence: 0.9908154606819153
#       bounding_poly {
#         normalized_vertices {
#           x: 0.22274509072303772
#           y: 0.26757577061653137
#         }
#         normalized_vertices {
#           x: 0.3964705765247345
#           y: 0.26757577061653137
#         }
#         normalized_vertices {
#           x: 0.3964705765247345
#           y: 0.2821212112903595
#         }
#         normalized_vertices {
#           x: 0.22274509072303772
#           y: 0.2821212112903595
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 875
#           end_index: 920
#         }
#       }
#       confidence: 0.9837625622749329
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12227543443441391
#           y: 0.8651515245437622
#         }
#         normalized_vertices {
#           x: 0.4678431451320648
#           y: 0.8651515245437622
#         }
#         normalized_vertices {
#           x: 0.4678431451320648
#           y: 0.8811370730400085
#         }
#         normalized_vertices {
#           x: 0.12227543443441391
#           y: 0.8811370730400085
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 920
#           end_index: 923
#         }
#       }
#       confidence: 0.9837625622749329
#       bounding_poly {
#         normalized_vertices {
#           x: 0.4941176474094391
#           y: 0.8672727346420288
#         }
#         normalized_vertices {
#           x: 0.5137255191802979
#           y: 0.8672727346420288
#         }
#         normalized_vertices {
#           x: 0.5137255191802979
#           y: 0.8772727251052856
#         }
#         normalized_vertices {
#           x: 0.4941176474094391
#           y: 0.8772727251052856
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 729
#           end_index: 746
#         }
#       }
#       confidence: 0.5744984745979309
#       bounding_poly {
#         normalized_vertices {
#           x: 0.4798126518726349
#           y: 0.7239394187927246
#         }
#         normalized_vertices {
#           x: 0.6128053069114685
#           y: 0.7239394187927246
#         }
#         normalized_vertices {
#           x: 0.6128053069114685
#           y: 0.7397733926773071
#         }
#         normalized_vertices {
#           x: 0.4798126518726349
#           y: 0.7397733926773071
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 746
#           end_index: 756
#         }
#       }
#       confidence: 0.5744984745979309
#       bounding_poly {
#         normalized_vertices {
#           x: 0.6227450966835022
#           y: 0.7239394187927246
#         }
#         normalized_vertices {
#           x: 0.701568603515625
#           y: 0.7239394187927246
#         }
#         normalized_vertices {
#           x: 0.701568603515625
#           y: 0.7396969795227051
#         }
#         normalized_vertices {
#           x: 0.6227450966835022
#           y: 0.7396969795227051
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 684
#           end_index: 718
#         }
#       }
#       confidence: 0.33455690741539
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11854321509599686
#           y: 0.7239394187927246
#         }
#         normalized_vertices {
#           x: 0.3866737484931946
#           y: 0.7239394187927246
#         }
#         normalized_vertices {
#           x: 0.3866737484931946
#           y: 0.7396969795227051
#         }
#         normalized_vertices {
#           x: 0.11854321509599686
#           y: 0.7396969795227051
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 718
#           end_index: 729
#         }
#       }
#       confidence: 0.33455690741539
#       bounding_poly {
#         normalized_vertices {
#           x: 0.3898039162158966
#           y: 0.7239394187927246
#         }
#         normalized_vertices {
#           x: 0.4749019742012024
#           y: 0.7239394187927246
#         }
#         normalized_vertices {
#           x: 0.4749019742012024
#           y: 0.7396969795227051
#         }
#         normalized_vertices {
#           x: 0.3898039162158966
#           y: 0.7396969795227051
#         }
#       }
#       orientation: 1
#     }
#   }
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 20
#       end_index: 48
#     }
#   }
#   mention_text: "0123456789"
#   mention_id: "0"
#   confidence: 0.9999972581863403
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 49
#       end_index: 75
#     }
#   }
#   mention_text: "01/01/2020"
#   mention_id: "1"
#   confidence: 0.999996542930603
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 164
#       end_index: 188
#     }
#   }
#   mention_text: "Mortgage company A"
#   mention_id: "2"
#   confidence: 0.9908154606819153
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 189
#       end_index: 243
#     }
#   }
#   mention_text: "100 Franklin Street, Mountain View, CA, 94035"
#   mention_id: "3"
#   confidence: 0.9999901056289673
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 244
#       end_index: 272
#     }
#   }
#   mention_text: "1-800-843-8623"
#   mention_id: "4"
#   confidence: 0.9999915957450867
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 333
#       end_index: 350
#     }
#   }
#   mention_text: "Arjun Patel"
#   mention_id: "5"
#   confidence: 0.999972939491272
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 394
#       end_index: 445
#     }
#   }
#   mention_text: "500 Castro Street, Mountain View, CA 94035"
#   mention_id: "6"
#   confidence: 0.9999908804893494
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 446
#       end_index: 472
#     }
#   }
#   mention_text: "650-987-0934"
#   mention_id: "7"
#   confidence: 0.9999571442604065
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 557
#       end_index: 595
#     }
#   }
#   mention_text: "2000"
#   mention_id: "8"
#   confidence: 0.9994090795516968
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 596
#       end_index: 621
#     }
#   }
#   mention_text: "6.0"
#   mention_id: "9"
#   confidence: 0.9930983185768127
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 684
#       end_index: 728
#     }
#   }
#   mention_text: "01/01/2020"
#   mention_id: "10"
#   confidence: 0.33455690741539
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 729
#       end_index: 756
#     }
#   }
#   mention_text: "12/31/2020"
#   mention_id: "11"
#   confidence: 0.5744984745979309
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 807
#       end_index: 849
#     }
#     text_segments {
#       start_index: 778
#       end_index: 783
#     }
#   }
#   mention_text: "38.67"
#   mention_id: "12"
#   confidence: 0.9998992681503296
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 784
#       end_index: 805
#     }
#   }
#   mention_text: "5\nyears"
#   mention_id: "13"
#   confidence: 0.9999465346336365
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 875
#       end_index: 922
#     }
#   }
#   mention_text: "40"
#   mention_id: "14"
#   confidence: 0.9837625622749329
# }
#
# Page number: 1
# Field Name: Agreement Number:
# 	Confidence: 0.9999972581863403
# Field Value: 0123456789
# 	Confidence: 0.9999972581863403
# Field Name: Agreement date:
# 	Confidence: 0.999996542930603
# Field Value: 01/01/2020
# 	Confidence: 0.999996542930603
# Field Name: Phone number: 	Confidence: 0.9999915957450867
# Field Value: 1-800-843-8623
# 	Confidence: 0.9999915957450867
# Field Name: Address:
# 	Confidence: 0.9999908804893494
# Field Value: 500 Castro Street, Mountain View, CA 94035
# 	Confidence: 0.9999908804893494
# Field Name: Address:
# 	Confidence: 0.9999901056289673
# Field Value: 100 Franklin Street, Mountain View, CA, 94035
# 	Confidence: 0.9999901056289673
# Field Name: Other 	Confidence: 0.9999788403511047
# Field Value: D
# 	Confidence: 0.9999788403511047
# Field Name: Married 	Confidence: 0.9999762177467346
# Field Value: O
# 	Confidence: 0.9999762177467346
# Field Name: Name:
# 	Confidence: 0.999972939491272
# Field Value: Arjun Patel
# 	Confidence: 0.999972939491272
# Field Name: Phone number: 	Confidence: 0.9999571442604065
# Field Value: 650-987-0934
# 	Confidence: 0.9999571442604065
# Field Name: Single 	Confidence: 0.999954879283905
# Field Value: ,
# 	Confidence: 0.999954879283905
# Field Name: per month for
# 	Confidence: 0.9999465346336365
# Field Value: 5
# years	Confidence: 0.9999465346336365
# Field Name: The borrower will pay an installment of $
# 	Confidence: 0.9998992681503296
# Field Value: 38.67
# 	Confidence: 0.9998992681503296
# Field Name: The lender is ready to sanction $
# 	Confidence: 0.9994090795516968
# Field Value: 2000
# 	Confidence: 0.9994090795516968
# Field Name: as the loan amount at
# 	Confidence: 0.9930983185768127
# Field Value: 6.0
# 	Confidence: 0.9930983185768127
# Field Name: Name:
# 	Confidence: 0.9908154606819153
# Field Value: Mortgage company A
# 	Confidence: 0.9908154606819153
# Field Name: Any late installment will be accepted with $
# 	Confidence: 0.9837625622749329
# Field Value: 40
# 	Confidence: 0.9837625622749329
# Field Name: and is ending on 	Confidence: 0.5744984745979309
# Field Value: 12/31/2020	Confidence: 0.5744984745979309
# Field Name: This loan agreement is valid from 	Confidence: 0.33455690741539
# Field Value: 01/01/2020 	Confidence: 0.33455690741539

# %% [markdown]
# ## b) Large file offline processing

# %% [markdown]
# - Asynchronous ("offline") requests targets longer documents and allows you to set the number of pages in the output files. This request starts a long-running operation. When this operation finishes it stores output as a JSON file in a specified Cloud Storage bucket.
#
#
# - Document AI asynchronous processing accepts PDF, TIFF, GIF files up to 2000 pages. Attempting to process larger files returns an error.
#
#
# - Use batch_process_documents method to send request to API.

# %%
def batch_parse_form(
        project_id,
        input_uri,
        destination_uri):
    """Parse a form"""

    client = documentai.DocumentUnderstandingServiceClient()

    gcs_source = documentai.types.GcsSource(uri=input_uri)

    # mime_type can be application/pdf, image/tiff,
    # and image/gif, or application/json
    input_config = documentai.types.InputConfig(
        gcs_source=gcs_source, mime_type='application/pdf')

    # where to write results
    output_config = documentai.types.OutputConfig(
        gcs_destination=documentai.types.GcsDestination(
            uri=destination_uri),
        pages_per_shard=1  # Map one doc page to one output page
    )

    # Improve form parsing results by providing key-value pair hints.
    # For each key hint, key is text that is likely to appear in the
    # document as a form field name (i.e. "DOB").
    # Value types are optional, but can be one or more of:
    # ADDRESS, LOCATION, ORGANIZATION, PERSON, PHONE_NUMBER, ID,
    # NUMBER, EMAIL, PRICE, TERMS, DATE, NAME
    key_value_pair_hints = [
        documentai.types.KeyValuePairHint(
            key='Emergency Contact',
            value_types=['NAME']),
        documentai.types.KeyValuePairHint(
            key='Referred By')
    ]

    # Setting enabled=True enables form extraction
    form_extraction_params = documentai.types.FormExtractionParams(
        enabled=True, key_value_pair_hints=key_value_pair_hints)

    # Location can be 'us' or 'eu'
    parent = 'projects/{}/locations/us'.format(project_id)
    request = documentai.types.ProcessDocumentRequest(
        input_config=input_config,
        output_config=output_config,
        form_extraction_params=form_extraction_params)

    # Add each ProcessDocumentRequest to the batch request
    requests = []
    requests.append(request)

    batch_request = documentai.types.BatchProcessDocumentsRequest(
        parent=parent, requests=requests
    )

    operation = client.batch_process_documents(batch_request)

    # Wait for the operation to finish
    operation.result()

    # Results are written to GCS. Use a regex to find
    # output files
    match = re.match(r'gs://([^/]+)/(.+)', destination_uri)
    output_bucket = match.group(1)
    prefix = match.group(2)

    storage_client = storage.client.Client()
    bucket = storage_client.get_bucket(output_bucket)
    blob_list = list(bucket.list_blobs(prefix=prefix))
    print('Output files:')
    for blob in blob_list:
        print(blob.name)

# %%
# calling above function

batch_parse_form(project_id="project-001-285307",input_uri="gs://bucket0406/form.pdf",destination_uri="gs://bucket0406/form_output.pdf")
# Out:
# Output files:
# form_output.pdf-output-page-1-to-1.json

# %% [markdown]
# It stores output as a JSON file in a specified Cloud Storage bucket.

# %% [markdown]
# # 2) Parsing documents containing tables

# %% [markdown]
# - Document AI can detect and parse text from PDF, TIFF, GIF files stored in Cloud Storage, including text that contains unstructured data in the form of tables.
#
# - You request table detection from a smaller file (<=5 pages) using the process method, and larger file requests (files with a large number of pages) use the batchProcess method. The status of batch (asynchronous) requests can be checked using the operations resources. Output from a batch request is written to a JSON file created in the specified Cloud Storage bucket.

# %% [markdown]
# ## a) Small file online processing

# %% [markdown]
# ### Parsing pdf form

# %% [markdown]
# - For Parsing pdf forms: mime type used is application/pdf
#
#
# - We can improve table parsing results by providing bounding boxes specifying where the box appears in the document (optional)
#
#
# - Created a Dataframe object with the exact structure as the table in form and saved it as csv file.

# %%
def parse_table_pdf(project_id,
                input_uri):
    """Parse a form"""

    client = documentai.DocumentUnderstandingServiceClient()

    gcs_source = documentai.types.GcsSource(uri=input_uri)

    # mime_type can be application/pdf, image/tiff,
    # and image/gif, or application/json
    input_config = documentai.types.InputConfig(
        gcs_source=gcs_source, mime_type='application/pdf')

    # Improve table parsing results by providing bounding boxes
    # specifying where the box appears in the document (optional)
    table_bound_hints = [
        documentai.types.TableBoundHint(
            page_number=1,
            bounding_box=documentai.types.BoundingPoly(
                # Define a polygon around tables to detect
                # Each vertice coordinate must be a number between 0 and 1
                normalized_vertices=[
                    # Top left
                    documentai.types.geometry.NormalizedVertex(
                        x=0,
                        y=0
                    ),
                    # Top right
                    documentai.types.geometry.NormalizedVertex(
                        x=1,
                        y=0
                    ),
                    # Bottom right
                    documentai.types.geometry.NormalizedVertex(
                        x=1,
                        y=1
                    ),
                    # Bottom left
                    documentai.types.geometry.NormalizedVertex(
                        x=0,
                        y=1
                    )
                ]
            )
        )
    ]

    # Setting enabled=True enables form extraction
    table_extraction_params = documentai.types.TableExtractionParams(
        enabled=True, table_bound_hints=table_bound_hints)

    # Location can be 'us' or 'eu'
    parent = 'projects/{}/locations/us'.format(project_id)
    request = documentai.types.ProcessDocumentRequest(
        parent=parent,
        input_config=input_config,
        table_extraction_params=table_extraction_params)

    document = client.process_document(request=request)
    print('document: \n',document)

    def _get_text(el):
        """Convert text offset indexes into text snippets.
        """
        response = ''
        # If a text segment spans several lines, it will
        # be stored in different text segments.
        for segment in el.text_anchor.text_segments:
            start_index = segment.start_index
            end_index = segment.end_index
            response += document.text[start_index:end_index]
        return response
    

    for page in document.pages:
        #print('Page number: {}'.format(page.page_number))
        for table_num, table in enumerate(page.tables):
            print('Table {}: '.format(table_num))
            for row_num, row in enumerate(table.header_rows):
                cells = '\t'.join(
                    [_get_text(cell.layout) for cell in row.cells])
                print('Header Row {}: {}'.format(row_num, cells))
                columns=[y for y in cells.split('\t')]
                columns=list(map(lambda x:x.strip(),columns))
                df3=pd.DataFrame()
            for row_num, row in enumerate(table.body_rows):
                cells = '\t'.join(
                    [_get_text(cell.layout) for cell in row.cells])
                print('Row {}: {}'.format(row_num, cells))
                l1=(cells.split('\t'))
                l1=list(map(lambda x:x.strip(),l1))
                df3=df3.append([l1],ignore_index=True)
            df3.columns=columns
            print('***********************************************************************')
            print('Dataframe with the exact structure as table in the form: \n\n', df3)
            df3.to_csv('invoice_table.csv')

# %%
parse_table_pdf("project-001-285307","gs://bucket0406/invoice.pdf")
# Out:
# document:
#  mime_type: "application/pdf"
# text: "TERMS: 6 month contract\nDUE: 01/01/2025\nNOTES:\nFROM: Company ABC\nuser@companyabc.com\nADDRESS: 111 Main Street\nAnytown, USA\nItem Description Quantity Price Amount\nTool A 500 $1.00 $500.00\nService B 1 $900.00 $900.00\nResource C 50 $12.00 $600.00\nSupplies used for Project Q.\nTO: John Doe\njohndoe@email.com\nADDRESS: 222 Main Street\nAnytown, USA\nSubtotal $2000.00\nTax $140.00\nBALANCE DUE $2140.00\nDATE: 01/01/1970\nINVOICE: NO. 001\nInvoice\n"
# pages {
#   page_number: 1
#   dimension {
#     width: 612.0
#     height: 792.0
#     unit: "points"
#   }
#   layout {
#     text_anchor {
#       text_segments {
#         end_index: 435
#       }
#     }
#     confidence: 1.0
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 612
#       }
#       vertices {
#         x: 612
#         y: 792
#       }
#       vertices {
#         y: 792
#       }
#       normalized_vertices {
#       }
#       normalized_vertices {
#         x: 1.0
#       }
#       normalized_vertices {
#         x: 1.0
#         y: 1.0
#       }
#       normalized_vertices {
#         y: 1.0
#       }
#     }
#     orientation: 1
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           end_index: 40
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.3712121248245239
#         }
#         normalized_vertices {
#           x: 0.32189542055130005
#           y: 0.3712121248245239
#         }
#         normalized_vertices {
#           x: 0.32189542055130005
#           y: 0.4027777910232544
#         }
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.4027777910232544
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 40
#           end_index: 47
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.7348484992980957
#         }
#         normalized_vertices {
#           x: 0.18300653994083405
#           y: 0.7348484992980957
#         }
#         normalized_vertices {
#           x: 0.18300653994083405
#           y: 0.747474730014801
#         }
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.747474730014801
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 47
#           end_index: 85
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.3937908411026001
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.3937908411026001
#           y: 0.2525252401828766
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.2525252401828766
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 85
#           end_index: 123
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.3042929172515869
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.3042929172515869
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 123
#           end_index: 162
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.4545454680919647
#         }
#         normalized_vertices {
#           x: 0.766339898109436
#           y: 0.4545454680919647
#         }
#         normalized_vertices {
#           x: 0.766339898109436
#           y: 0.46717172861099243
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.46717172861099243
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 162
#           end_index: 187
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.4848484992980957
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.4848484992980957
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.4974747598171234
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.4974747598171234
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 187
#           end_index: 215
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.5164141654968262
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.5164141654968262
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.5290403962135315
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.5290403962135315
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 215
#           end_index: 244
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.5479797720909119
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.5479797720909119
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.560606062412262
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.560606062412262
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 244
#           end_index: 273
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.7803030014038086
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.7803030014038086
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.7929292917251587
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.7929292917251587
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 273
#           end_index: 304
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.7156862616539001
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.7156862616539001
#           y: 0.2525252401828766
#         }
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.2525252401828766
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 304
#           end_index: 342
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.7303921580314636
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.7303921580314636
#           y: 0.3042929172515869
#         }
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.3042929172515869
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 342
#           end_index: 360
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.6098484992980957
#         }
#         normalized_vertices {
#           x: 0.7728758454322815
#           y: 0.6098484992980957
#         }
#         normalized_vertices {
#           x: 0.7728758454322815
#           y: 0.622474730014801
#         }
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.622474730014801
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 360
#           end_index: 372
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.6414141654968262
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.6414141654968262
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.6540403962135315
#         }
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.6540403962135315
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 372
#           end_index: 393
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.6729797720909119
#         }
#         normalized_vertices {
#           x: 0.7728758454322815
#           y: 0.6729797720909119
#         }
#         normalized_vertices {
#           x: 0.7728758454322815
#           y: 0.685606062412262
#         }
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.685606062412262
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 393
#           end_index: 427
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7320261597633362
#           y: 0.1401515156030655
#         }
#         normalized_vertices {
#           x: 0.8807189464569092
#           y: 0.1401515156030655
#         }
#         normalized_vertices {
#           x: 0.8807189464569092
#           y: 0.17171716690063477
#         }
#         normalized_vertices {
#           x: 0.7320261597633362
#           y: 0.17171716690063477
#         }
#       }
#       orientation: 1
#     }
#   }
#   blocks {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 427
#           end_index: 435
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7483659982681274
#           y: 0.08964646607637405
#         }
#         normalized_vertices {
#           x: 0.8790849447250366
#           y: 0.08964646607637405
#         }
#         normalized_vertices {
#           x: 0.8790849447250366
#           y: 0.12121212482452393
#         }
#         normalized_vertices {
#           x: 0.7483659982681274
#           y: 0.12121212482452393
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           end_index: 40
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.3712121248245239
#         }
#         normalized_vertices {
#           x: 0.32189542055130005
#           y: 0.3712121248245239
#         }
#         normalized_vertices {
#           x: 0.32189542055130005
#           y: 0.4027777910232544
#         }
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.4027777910232544
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 40
#           end_index: 47
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.7348484992980957
#         }
#         normalized_vertices {
#           x: 0.18300653994083405
#           y: 0.7348484992980957
#         }
#         normalized_vertices {
#           x: 0.18300653994083405
#           y: 0.747474730014801
#         }
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.747474730014801
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 47
#           end_index: 85
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.3937908411026001
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.3937908411026001
#           y: 0.2525252401828766
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.2525252401828766
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 85
#           end_index: 123
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.3042929172515869
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.3042929172515869
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 123
#           end_index: 162
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.4545454680919647
#         }
#         normalized_vertices {
#           x: 0.766339898109436
#           y: 0.4545454680919647
#         }
#         normalized_vertices {
#           x: 0.766339898109436
#           y: 0.46717172861099243
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.46717172861099243
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 162
#           end_index: 187
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.4848484992980957
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.4848484992980957
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.4974747598171234
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.4974747598171234
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 187
#           end_index: 215
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.5164141654968262
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.5164141654968262
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.5290403962135315
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.5290403962135315
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 215
#           end_index: 244
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.5479797720909119
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.5479797720909119
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.560606062412262
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.560606062412262
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 244
#           end_index: 273
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.7803030014038086
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.7803030014038086
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.7929292917251587
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.7929292917251587
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 273
#           end_index: 304
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.7156862616539001
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.7156862616539001
#           y: 0.2525252401828766
#         }
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.2525252401828766
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 304
#           end_index: 342
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.7303921580314636
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.7303921580314636
#           y: 0.3042929172515869
#         }
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.3042929172515869
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 342
#           end_index: 360
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.6098484992980957
#         }
#         normalized_vertices {
#           x: 0.7728758454322815
#           y: 0.6098484992980957
#         }
#         normalized_vertices {
#           x: 0.7728758454322815
#           y: 0.622474730014801
#         }
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.622474730014801
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 360
#           end_index: 372
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.6414141654968262
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.6414141654968262
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.6540403962135315
#         }
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.6540403962135315
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 372
#           end_index: 393
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.6729797720909119
#         }
#         normalized_vertices {
#           x: 0.7728758454322815
#           y: 0.6729797720909119
#         }
#         normalized_vertices {
#           x: 0.7728758454322815
#           y: 0.685606062412262
#         }
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.685606062412262
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 393
#           end_index: 427
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7320261597633362
#           y: 0.1401515156030655
#         }
#         normalized_vertices {
#           x: 0.8807189464569092
#           y: 0.1401515156030655
#         }
#         normalized_vertices {
#           x: 0.8807189464569092
#           y: 0.17171716690063477
#         }
#         normalized_vertices {
#           x: 0.7320261597633362
#           y: 0.17171716690063477
#         }
#       }
#       orientation: 1
#     }
#   }
#   paragraphs {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 427
#           end_index: 435
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7483659982681274
#           y: 0.08964646607637405
#         }
#         normalized_vertices {
#           x: 0.8790849447250366
#           y: 0.08964646607637405
#         }
#         normalized_vertices {
#           x: 0.8790849447250366
#           y: 0.12121212482452393
#         }
#         normalized_vertices {
#           x: 0.7483659982681274
#           y: 0.12121212482452393
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           end_index: 24
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.3712121248245239
#         }
#         normalized_vertices {
#           x: 0.32189542055130005
#           y: 0.3712121248245239
#         }
#         normalized_vertices {
#           x: 0.32189542055130005
#           y: 0.38383838534355164
#         }
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.38383838534355164
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 24
#           end_index: 40
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.3901515007019043
#         }
#         normalized_vertices {
#           x: 0.25326797366142273
#           y: 0.3901515007019043
#         }
#         normalized_vertices {
#           x: 0.25326797366142273
#           y: 0.4027777910232544
#         }
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.4027777910232544
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 40
#           end_index: 47
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.7348484992980957
#         }
#         normalized_vertices {
#           x: 0.18300653994083405
#           y: 0.7348484992980957
#         }
#         normalized_vertices {
#           x: 0.18300653994083405
#           y: 0.747474730014801
#         }
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.747474730014801
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 47
#           end_index: 65
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.31699347496032715
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.31699347496032715
#           y: 0.2361111044883728
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.2361111044883728
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 65
#           end_index: 85
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.20098039507865906
#           y: 0.23989899456501007
#         }
#         normalized_vertices {
#           x: 0.3937908411026001
#           y: 0.23989899456501007
#         }
#         normalized_vertices {
#           x: 0.3937908411026001
#           y: 0.2525252401828766
#         }
#         normalized_vertices {
#           x: 0.20098039507865906
#           y: 0.2525252401828766
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 85
#           end_index: 110
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.28661617636680603
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.28661617636680603
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 110
#           end_index: 123
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.22549019753932953
#           y: 0.2916666567325592
#         }
#         normalized_vertices {
#           x: 0.33986929059028625
#           y: 0.2916666567325592
#         }
#         normalized_vertices {
#           x: 0.33986929059028625
#           y: 0.3042929172515869
#         }
#         normalized_vertices {
#           x: 0.22549019753932953
#           y: 0.3042929172515869
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 123
#           end_index: 162
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.4545454680919647
#         }
#         normalized_vertices {
#           x: 0.766339898109436
#           y: 0.4545454680919647
#         }
#         normalized_vertices {
#           x: 0.766339898109436
#           y: 0.46717172861099243
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.46717172861099243
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 162
#           end_index: 187
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.4848484992980957
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.4848484992980957
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.4974747598171234
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.4974747598171234
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 187
#           end_index: 215
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.5164141654968262
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.5164141654968262
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.5290403962135315
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.5290403962135315
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 215
#           end_index: 244
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.5479797720909119
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.5479797720909119
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.560606062412262
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.560606062412262
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 244
#           end_index: 273
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.7803030014038086
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.7803030014038086
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.7929292917251587
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.7929292917251587
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 273
#           end_index: 286
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.6290849447250366
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.6290849447250366
#           y: 0.2361111044883728
#         }
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.2361111044883728
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 286
#           end_index: 304
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.5539215803146362
#           y: 0.23989899456501007
#         }
#         normalized_vertices {
#           x: 0.7156862616539001
#           y: 0.23989899456501007
#         }
#         normalized_vertices {
#           x: 0.7156862616539001
#           y: 0.2525252401828766
#         }
#         normalized_vertices {
#           x: 0.5539215803146362
#           y: 0.2525252401828766
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 304
#           end_index: 329
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.7303921580314636
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.7303921580314636
#           y: 0.28661617636680603
#         }
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.28661617636680603
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 329
#           end_index: 342
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.6029411554336548
#           y: 0.2916666567325592
#         }
#         normalized_vertices {
#           x: 0.7173202633857727
#           y: 0.2916666567325592
#         }
#         normalized_vertices {
#           x: 0.7173202633857727
#           y: 0.3042929172515869
#         }
#         normalized_vertices {
#           x: 0.6029411554336548
#           y: 0.3042929172515869
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 342
#           end_index: 360
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.6098484992980957
#         }
#         normalized_vertices {
#           x: 0.7728758454322815
#           y: 0.6098484992980957
#         }
#         normalized_vertices {
#           x: 0.7728758454322815
#           y: 0.622474730014801
#         }
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.622474730014801
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 360
#           end_index: 372
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.6414141654968262
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.6414141654968262
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.6540403962135315
#         }
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.6540403962135315
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 372
#           end_index: 393
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.6729797720909119
#         }
#         normalized_vertices {
#           x: 0.7728758454322815
#           y: 0.6729797720909119
#         }
#         normalized_vertices {
#           x: 0.7728758454322815
#           y: 0.685606062412262
#         }
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.685606062412262
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 393
#           end_index: 410
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.733660101890564
#           y: 0.1401515156030655
#         }
#         normalized_vertices {
#           x: 0.8790849447250366
#           y: 0.1401515156030655
#         }
#         normalized_vertices {
#           x: 0.8790849447250366
#           y: 0.1527777761220932
#         }
#         normalized_vertices {
#           x: 0.733660101890564
#           y: 0.1527777761220932
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 410
#           end_index: 427
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7320261597633362
#           y: 0.15909090638160706
#         }
#         normalized_vertices {
#           x: 0.8807189464569092
#           y: 0.15909090638160706
#         }
#         normalized_vertices {
#           x: 0.8807189464569092
#           y: 0.17171716690063477
#         }
#         normalized_vertices {
#           x: 0.7320261597633362
#           y: 0.17171716690063477
#         }
#       }
#       orientation: 1
#     }
#   }
#   lines {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 427
#           end_index: 435
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7483659982681274
#           y: 0.08964646607637405
#         }
#         normalized_vertices {
#           x: 0.8790849447250366
#           y: 0.08964646607637405
#         }
#         normalized_vertices {
#           x: 0.8790849447250366
#           y: 0.12121212482452393
#         }
#         normalized_vertices {
#           x: 0.7483659982681274
#           y: 0.12121212482452393
#         }
#       }
#       orientation: 1
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           end_index: 7
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.3712121248245239
#         }
#         normalized_vertices {
#           x: 0.18300653994083405
#           y: 0.3712121248245239
#         }
#         normalized_vertices {
#           x: 0.18300653994083405
#           y: 0.38383838534355164
#         }
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.38383838534355164
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 7
#           end_index: 9
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.19117647409439087
#           y: 0.3712121248245239
#         }
#         normalized_vertices {
#           x: 0.1993464082479477
#           y: 0.3712121248245239
#         }
#         normalized_vertices {
#           x: 0.1993464082479477
#           y: 0.38383838534355164
#         }
#         normalized_vertices {
#           x: 0.19117647409439087
#           y: 0.38383838534355164
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 9
#           end_index: 15
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.20588235557079315
#           y: 0.3712121248245239
#         }
#         normalized_vertices {
#           x: 0.25326797366142273
#           y: 0.3712121248245239
#         }
#         normalized_vertices {
#           x: 0.25326797366142273
#           y: 0.38383838534355164
#         }
#         normalized_vertices {
#           x: 0.20588235557079315
#           y: 0.38383838534355164
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 15
#           end_index: 24
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.2598039209842682
#           y: 0.3712121248245239
#         }
#         normalized_vertices {
#           x: 0.32189542055130005
#           y: 0.3712121248245239
#         }
#         normalized_vertices {
#           x: 0.32189542055130005
#           y: 0.38383838534355164
#         }
#         normalized_vertices {
#           x: 0.2598039209842682
#           y: 0.38383838534355164
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 2
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 24
#           end_index: 29
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.3901515007019043
#         }
#         normalized_vertices {
#           x: 0.15849673748016357
#           y: 0.3901515007019043
#         }
#         normalized_vertices {
#           x: 0.15849673748016357
#           y: 0.4027777910232544
#         }
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.4027777910232544
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 29
#           end_index: 40
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.16503268480300903
#           y: 0.3901515007019043
#         }
#         normalized_vertices {
#           x: 0.25326797366142273
#           y: 0.3901515007019043
#         }
#         normalized_vertices {
#           x: 0.25326797366142273
#           y: 0.4027777910232544
#         }
#         normalized_vertices {
#           x: 0.16503268480300903
#           y: 0.4027777910232544
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 2
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 40
#           end_index: 47
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.7348484992980957
#         }
#         normalized_vertices {
#           x: 0.18300653994083405
#           y: 0.7348484992980957
#         }
#         normalized_vertices {
#           x: 0.18300653994083405
#           y: 0.747474730014801
#         }
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.747474730014801
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 2
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 47
#           end_index: 53
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.18300653994083405
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.18300653994083405
#           y: 0.2361111044883728
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.2361111044883728
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 53
#           end_index: 61
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.1993464082479477
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.27450981736183167
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.27450981736183167
#           y: 0.2361111044883728
#         }
#         normalized_vertices {
#           x: 0.1993464082479477
#           y: 0.2361111044883728
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 61
#           end_index: 65
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.2810457646846771
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.31699347496032715
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.31699347496032715
#           y: 0.2361111044883728
#         }
#         normalized_vertices {
#           x: 0.2810457646846771
#           y: 0.2361111044883728
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 2
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 65
#           end_index: 85
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.20098039507865906
#           y: 0.23989899456501007
#         }
#         normalized_vertices {
#           x: 0.3937908411026001
#           y: 0.23989899456501007
#         }
#         normalized_vertices {
#           x: 0.3937908411026001
#           y: 0.2525252401828766
#         }
#         normalized_vertices {
#           x: 0.20098039507865906
#           y: 0.2525252401828766
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 2
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 85
#           end_index: 94
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.21568627655506134
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.21568627655506134
#           y: 0.28661617636680603
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.28661617636680603
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 94
#           end_index: 98
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.22385621070861816
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.25163400173187256
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.25163400173187256
#           y: 0.28661617636680603
#         }
#         normalized_vertices {
#           x: 0.22385621070861816
#           y: 0.28661617636680603
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 98
#           end_index: 103
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.258169949054718
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.2957516312599182
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.2957516312599182
#           y: 0.28661617636680603
#         }
#         normalized_vertices {
#           x: 0.258169949054718
#           y: 0.28661617636680603
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 103
#           end_index: 110
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.30228757858276367
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.28661617636680603
#         }
#         normalized_vertices {
#           x: 0.30228757858276367
#           y: 0.28661617636680603
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 2
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 110
#           end_index: 119
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.22549019753932953
#           y: 0.2916666567325592
#         }
#         normalized_vertices {
#           x: 0.29738563299179077
#           y: 0.2916666567325592
#         }
#         normalized_vertices {
#           x: 0.29738563299179077
#           y: 0.3042929172515869
#         }
#         normalized_vertices {
#           x: 0.22549019753932953
#           y: 0.3042929172515869
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 119
#           end_index: 123
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.3055555522441864
#           y: 0.2916666567325592
#         }
#         normalized_vertices {
#           x: 0.33986929059028625
#           y: 0.2916666567325592
#         }
#         normalized_vertices {
#           x: 0.33986929059028625
#           y: 0.3042929172515869
#         }
#         normalized_vertices {
#           x: 0.3055555522441864
#           y: 0.3042929172515869
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 2
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 123
#           end_index: 128
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.4545454680919647
#         }
#         normalized_vertices {
#           x: 0.1617647111415863
#           y: 0.4545454680919647
#         }
#         normalized_vertices {
#           x: 0.1617647111415863
#           y: 0.46717172861099243
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.46717172861099243
#         }
#       }
#       orientation: 1
#     }
#     detected_break {
#       type: 1
#     }
#   }
#   tokens {
#     layout {
#       text_anchor {
#         text_segments {
#           start_index: 128
#           end_index: 140
#         }
#       }
#       confidence: 1.0
#       bounding_poly {
#         normalized_vertices {
#           x: 0.16830065846443176
# ...
#           y: 0.3853254020214081
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 7
#           end_index: 24
#         }
#       }
#       confidence: 0.9613451361656189
#       bounding_poly {
#         normalized_vertices {
#           x: 0.19117647409439087
#           y: 0.3712121248245239
#         }
#         normalized_vertices {
#           x: 0.32189542055130005
#           y: 0.3712121248245239
#         }
#         normalized_vertices {
#           x: 0.32189542055130005
#           y: 0.38383838534355164
#         }
#         normalized_vertices {
#           x: 0.19117647409439087
#           y: 0.38383838534355164
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 304
#           end_index: 313
#         }
#       }
#       confidence: 0.9588744640350342
#       bounding_poly {
#         normalized_vertices {
#           x: 0.5081024765968323
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.6002252101898193
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.6002252101898193
#           y: 0.2883654236793518
#         }
#         normalized_vertices {
#           x: 0.5081024765968323
#           y: 0.2883654236793518
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 273
#           end_index: 342
#         }
#       }
#       confidence: 0.9588744640350342
#       bounding_poly {
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.7303921580314636
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.7303921580314636
#           y: 0.3042929172515869
#         }
#         normalized_vertices {
#           x: 0.508169949054718
#           y: 0.3042929172515869
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 393
#           end_index: 399
#         }
#       }
#       confidence: 0.9502831101417542
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7332303524017334
#           y: 0.1401515156030655
#         }
#         normalized_vertices {
#           x: 0.7866594791412354
#           y: 0.1401515156030655
#         }
#         normalized_vertices {
#           x: 0.7866594791412354
#           y: 0.1543579250574112
#         }
#         normalized_vertices {
#           x: 0.7332303524017334
#           y: 0.1543579250574112
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 399
#           end_index: 410
#         }
#       }
#       confidence: 0.9502831101417542
#       bounding_poly {
#         normalized_vertices {
#           x: 0.7924836874008179
#           y: 0.1401515156030655
#         }
#         normalized_vertices {
#           x: 0.8790849447250366
#           y: 0.1401515156030655
#         }
#         normalized_vertices {
#           x: 0.8790849447250366
#           y: 0.1527777761220932
#         }
#         normalized_vertices {
#           x: 0.7924836874008179
#           y: 0.1527777761220932
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 24
#           end_index: 29
#         }
#       }
#       confidence: 0.9132761359214783
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.3901515007019043
#         }
#         normalized_vertices {
#           x: 0.1603870391845703
#           y: 0.3901515007019043
#         }
#         normalized_vertices {
#           x: 0.1603870391845703
#           y: 0.4041357934474945
#         }
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.4041357934474945
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 29
#           end_index: 40
#         }
#       }
#       confidence: 0.9132761359214783
#       bounding_poly {
#         normalized_vertices {
#           x: 0.16503268480300903
#           y: 0.3901515007019043
#         }
#         normalized_vertices {
#           x: 0.25326797366142273
#           y: 0.3901515007019043
#         }
#         normalized_vertices {
#           x: 0.25326797366142273
#           y: 0.4027777910232544
#         }
#         normalized_vertices {
#           x: 0.16503268480300903
#           y: 0.4027777910232544
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 273
#           end_index: 277
#         }
#       }
#       confidence: 0.873681902885437
#       bounding_poly {
#         normalized_vertices {
#           x: 0.5081536769866943
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.5375816822052002
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.5375816822052002
#           y: 0.23754334449768066
#         }
#         normalized_vertices {
#           x: 0.5081536769866943
#           y: 0.23754334449768066
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 277
#           end_index: 304
#         }
#       }
#       confidence: 0.873681902885437
#       bounding_poly {
#         normalized_vertices {
#           x: 0.5539215803146362
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.7156862616539001
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.7156862616539001
#           y: 0.2525252401828766
#         }
#         normalized_vertices {
#           x: 0.5539215803146362
#           y: 0.2525252401828766
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 85
#           end_index: 94
#         }
#       }
#       confidence: 0.6812911033630371
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.21682296693325043
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.21682296693325043
#           y: 0.2885611653327942
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.2885611653327942
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 94
#           end_index: 123
#         }
#       }
#       confidence: 0.6812911033630371
#       bounding_poly {
#         normalized_vertices {
#           x: 0.22385621070861816
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.27398988604545593
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.3042929172515869
#         }
#         normalized_vertices {
#           x: 0.22385621070861816
#           y: 0.3042929172515869
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 40
#           end_index: 47
#         }
#       }
#       confidence: 0.5695251226425171
#       bounding_poly {
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.7348484992980957
#         }
#         normalized_vertices {
#           x: 0.1840456873178482
#           y: 0.7348484992980957
#         }
#         normalized_vertices {
#           x: 0.1840456873178482
#           y: 0.7494825124740601
#         }
#         normalized_vertices {
#           x: 0.11764705926179886
#           y: 0.7494825124740601
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 244
#           end_index: 273
#         }
#       }
#       confidence: 0.5695251226425171
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.7803030014038086
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.7803030014038086
#         }
#         normalized_vertices {
#           x: 0.3480392098426819
#           y: 0.7929292917251587
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.7929292917251587
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 342
#           end_index: 351
#         }
#       }
#       confidence: 0.5455163717269897
#       bounding_poly {
#         normalized_vertices {
#           x: 0.5066612362861633
#           y: 0.6098484992980957
#         }
#         normalized_vertices {
#           x: 0.5788960456848145
#           y: 0.6098484992980957
#         }
#         normalized_vertices {
#           x: 0.5788960456848145
#           y: 0.6252211332321167
#         }
#         normalized_vertices {
#           x: 0.5066612362861633
#           y: 0.6252211332321167
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 351
#           end_index: 360
#         }
#       }
#       confidence: 0.5455163717269897
#       bounding_poly {
#         normalized_vertices {
#           x: 0.6993464231491089
#           y: 0.6098484992980957
#         }
#         normalized_vertices {
#           x: 0.7728758454322815
#           y: 0.6098484992980957
#         }
#         normalized_vertices {
#           x: 0.7728758454322815
#           y: 0.622474730014801
#         }
#         normalized_vertices {
#           x: 0.6993464231491089
#           y: 0.622474730014801
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 360
#           end_index: 364
#         }
#       }
#       confidence: 0.5170946717262268
#       bounding_poly {
#         normalized_vertices {
#           x: 0.5069932341575623
#           y: 0.6414141654968262
#         }
#         normalized_vertices {
#           x: 0.5400316119194031
#           y: 0.6414141654968262
#         }
#         normalized_vertices {
#           x: 0.5400316119194031
#           y: 0.6566182374954224
#         }
#         normalized_vertices {
#           x: 0.5069932341575623
#           y: 0.6566182374954224
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 364
#           end_index: 372
#         }
#       }
#       confidence: 0.5170946717262268
#       bounding_poly {
#         normalized_vertices {
#           x: 0.6993464231491089
#           y: 0.6414141654968262
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.6414141654968262
#         }
#         normalized_vertices {
#           x: 0.7630718946456909
#           y: 0.6540403962135315
#         }
#         normalized_vertices {
#           x: 0.6993464231491089
#           y: 0.6540403962135315
#         }
#       }
#       orientation: 1
#     }
#   }
#   form_fields {
#     field_name {
#       text_anchor {
#         text_segments {
#           start_index: 53
#           end_index: 65
#         }
#       }
#       confidence: 0.1373336911201477
#       bounding_poly {
#         normalized_vertices {
#           x: 0.18699859082698822
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.31699347496032715
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.31699347496032715
#           y: 0.23993688821792603
#         }
#         normalized_vertices {
#           x: 0.18699859082698822
#           y: 0.23993688821792603
#         }
#       }
#       orientation: 1
#     }
#     field_value {
#       text_anchor {
#         text_segments {
#           start_index: 47
#           end_index: 123
#         }
#       }
#       confidence: 0.1373336911201477
#       bounding_poly {
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.3937908411026001
#           y: 0.2234848439693451
#         }
#         normalized_vertices {
#           x: 0.3937908411026001
#           y: 0.3042929172515869
#         }
#         normalized_vertices {
#           x: 0.12581700086593628
#           y: 0.3042929172515869
#         }
#       }
#       orientation: 1
#     }
#   }
# }
# entities {
#   text_anchor {
#     text_segments {
#       end_index: 23
#     }
#   }
#   mention_text: "6 month contract"
#   mention_id: "0"
#   confidence: 0.9613451361656189
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 24
#       end_index: 39
#     }
#   }
#   mention_text: "01/01/2025"
#   mention_id: "1"
#   confidence: 0.9132761359214783
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 40
#       end_index: 47
#     }
#     text_segments {
#       start_index: 244
#       end_index: 272
#     }
#   }
#   mention_text: "Supplies used for Project Q."
#   mention_id: "2"
#   confidence: 0.5695251226425171
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 47
#       end_index: 84
#     }
#   }
#   mention_text: "Company ABC\nuser@companyabc.com"
#   mention_id: "3"
#   confidence: 0.9672579765319824
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 53
#       end_index: 65
#     }
#     text_segments {
#       start_index: 47
#       end_index: 122
#     }
#   }
#   mention_text: "FROM: Company ABC\nuser@companyabc.com\nADDRESS: 111 Main Street\nAnytown, USA"
#   mention_id: "4"
#   confidence: 0.1373336911201477
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 85
#       end_index: 122
#     }
#   }
#   mention_text: "111 Main Street\nAnytown, USA"
#   mention_id: "5"
#   confidence: 0.6812911033630371
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 273
#       end_index: 303
#     }
#   }
#   mention_text: "John Doe\njohndoe@email.com"
#   mention_id: "6"
#   confidence: 0.873681902885437
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 304
#       end_index: 313
#     }
#     text_segments {
#       start_index: 273
#       end_index: 341
#     }
#   }
#   mention_text: "TO: John Doe\njohndoe@email.com\nADDRESS: 222 Main Street\nAnytown, USA"
#   mention_id: "7"
#   confidence: 0.9588744640350342
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 342
#       end_index: 359
#     }
#   }
#   mention_text: "$2000.00"
#   mention_id: "8"
#   confidence: 0.5455163717269897
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 360
#       end_index: 371
#     }
#   }
#   mention_text: "$140.00"
#   mention_id: "9"
#   confidence: 0.5170946717262268
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 372
#       end_index: 392
#     }
#   }
#   mention_text: "$2140.00"
#   mention_id: "10"
#   confidence: 0.9981581568717957
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 393
#       end_index: 409
#     }
#   }
#   mention_text: "01/01/1970"
#   mention_id: "11"
#   confidence: 0.9502831101417542
# }
# entities {
#   text_anchor {
#     text_segments {
#       start_index: 410
#       end_index: 426
#     }
#   }
#   mention_text: "NO. 001"
#   mention_id: "12"
#   confidence: 0.9670966863632202
# }
#
# Table 0:
# Header Row 0: Item Description 	Quantity 	Price 	Amount
#
# Row 0: Tool A 	500 	$1.00 	$500.00
#
# Row 1: Service B 	1 	$900.00 	$900.00
#
# Row 2: Resource C 	50 	$12.00 	$600.00
#
# Row 3: 		Subtotal 	$2000.00
#
# Row 4: 		Tax 	$140.00
#
# Row 5: 		BALANCE DUE 	$2140.00
#
# ***********************************************************************
# Dataframe with the exact structure as table in the form:
#
#    Item Description Quantity        Price    Amount
# 0           Tool A      500        $1.00   $500.00
# 1        Service B        1      $900.00   $900.00
# 2       Resource C       50       $12.00   $600.00
# 3                               Subtotal  $2000.00
# 4                                    Tax   $140.00
# 5                            BALANCE DUE  $2140.00

# %% [markdown]
# ### Parsing tiff images

# %% [markdown]
# -  For Parsing pdf forms: mime type used is image/tiff
#
#
# - Created a Dataframe object with the exact structure as the table in form and saved it as csv file.

# %%
def parse_table_tiff(project_id,
                input_uri):
    """Parse a form"""

    client = documentai.DocumentUnderstandingServiceClient()

    gcs_source = documentai.types.GcsSource(uri=input_uri)

    # mime_type can be application/pdf, image/tiff,
    # and image/gif, or application/json
    input_config = documentai.types.InputConfig(
        gcs_source=gcs_source, mime_type='image/tiff')

    # Improve table parsing results by providing bounding boxes
    # specifying where the box appears in the document (optional)
    table_bound_hints = [
        documentai.types.TableBoundHint(
            page_number=1,
            bounding_box=documentai.types.BoundingPoly(
                # Define a polygon around tables to detect
                # Each vertice coordinate must be a number between 0 and 1
                normalized_vertices=[
                    # Top left
                    documentai.types.geometry.NormalizedVertex(
                        x=0,
                        y=0
                    ),
                    # Top right
                    documentai.types.geometry.NormalizedVertex(
                        x=1,
                        y=0
                    ),
                    # Bottom right
                    documentai.types.geometry.NormalizedVertex(
                        x=1,
                        y=1
                    ),
                    # Bottom left
                    documentai.types.geometry.NormalizedVertex(
                        x=0,
                        y=1
                    )
                ]
            )
        )
    ]

    # Setting enabled=True enables form extraction
    table_extraction_params = documentai.types.TableExtractionParams(
        enabled=True, table_bound_hints=table_bound_hints)

    # Location can be 'us' or 'eu'
    parent = 'projects/{}/locations/us'.format(project_id)
    request = documentai.types.ProcessDocumentRequest(
        parent=parent,
        input_config=input_config,
        table_extraction_params=table_extraction_params)

    document = client.process_document(request=request)
    #print('document: \n',document)

    def _get_text(el):
        """Convert text offset indexes into text snippets.
        """
        response = ''
        # If a text segment spans several lines, it will
        # be stored in different text segments.
        for segment in el.text_anchor.text_segments:
            start_index = segment.start_index
            end_index = segment.end_index
            response += document.text[start_index:end_index]
        return response
    

    for page in document.pages:
        #print('Page number: {}'.format(page.page_number))
        for table_num, table in enumerate(page.tables):
            print('Table {}: '.format(table_num))
            for row_num, row in enumerate(table.header_rows):
                cells = '\t'.join(
                    [_get_text(cell.layout) for cell in row.cells])
                print('Header Row {}: {}'.format(row_num, cells))
                columns=[y for y in cells.split('\t')]
                columns=list(map(lambda x:x.strip(),columns))
                df3=pd.DataFrame()
            for row_num, row in enumerate(table.body_rows):
                cells = '\t'.join(
                    [_get_text(cell.layout) for cell in row.cells])
                print('Row {}: {}'.format(row_num, cells))
                l1=(cells.split('\t'))
                l1=list(map(lambda x:x.strip(),l1))
                df3=df3.append([l1],ignore_index=True)
            df3.columns=columns
            print('***********************************************************************')
            print('Dataframe with the exact structure as table in the form: \n\n', df3)
            df3.to_csv('invoice1.csv')

# %%
parse_table_tiff("project-001-285307","gs://bucket0406/invoice1.tiff")
# Out:
# Table 0:
# Header Row 0: DESCRIPTION
# 	UNIT COST
# 	QTY/HR RATE
# 	AMOUNT
#
# Row 0: Your item name
# 	$0
# 	1
# 	$0
#
# Row 1: Your item name
# 	$0
# 	1
# 	$0
#
# Row 2: Your item name
# 	$0
# 	1
# 	$0
#
# Row 3: Your item name
# 	$0
# 	1
# 	$0
#
# Row 4: Your item name
# 	$0
# 	1
# 	$0
#
# Row 5: Your item name
# 	$0
# 	1
# 	$0
#
# Row 6: Your item name
# 	$0
# 	1
# 	$0
#
# ***********************************************************************
# Dataframe with the exact structure as table in the form:
#
#        DESCRIPTION UNIT COST QTY/HR RATE AMOUNT
# 0  Your item name        $0           1     $0
# 1  Your item name        $0           1     $0
# 2  Your item name        $0           1     $0
# 3  Your item name        $0           1     $0
# 4  Your item name        $0           1     $0
# 5  Your item name        $0           1     $0
# 6  Your item name        $0           1     $0

# %% [markdown]
# ## b) Large file offline processing

# %%
def batch_parse_table(
        project_id,
        input_uri,
        destination_uri):
    """Parse a form"""

    client = documentai.DocumentUnderstandingServiceClient()

    gcs_source = documentai.types.GcsSource(uri=input_uri)

    # mime_type can be application/pdf, image/tiff,
    # and image/gif, or application/json
    input_config = documentai.types.InputConfig(
        gcs_source=gcs_source, mime_type='application/pdf')

    # where to write results
    output_config = documentai.types.OutputConfig(
        gcs_destination=documentai.types.GcsDestination(
            uri=destination_uri),
        pages_per_shard=1  # Map one doc page to one output page
    )

    # Improve table parsing results by providing bounding boxes
    # specifying where the box appears in the document (optional)
    table_bound_hints = [
        documentai.types.TableBoundHint(
            page_number=1,
            bounding_box=documentai.types.BoundingPoly(
                # Define a polygon around tables to detect
                # Each vertice coordinate must be a number between 0 and 1
                normalized_vertices=[
                    # Top left
                    documentai.types.geometry.NormalizedVertex(
                        x=0,
                        y=0
                    ),
                    # Top right
                    documentai.types.geometry.NormalizedVertex(
                        x=1,
                        y=0
                    ),
                    # Bottom right
                    documentai.types.geometry.NormalizedVertex(
                        x=1,
                        y=1
                    ),
                    # Bottom left
                    documentai.types.geometry.NormalizedVertex(
                        x=0,
                        y=1
                    )
                ]
            )
        )
    ]

    # Setting enabled=True enables form extraction
    table_extraction_params = documentai.types.TableExtractionParams(
        enabled=True, table_bound_hints=table_bound_hints)

    # Location can be 'us' or 'eu'
    parent = 'projects/{}/locations/us'.format(project_id)
    request = documentai.types.ProcessDocumentRequest(
        input_config=input_config,
        output_config=output_config,
        table_extraction_params=table_extraction_params)

    requests = []
    requests.append(request)

    batch_request = documentai.types.BatchProcessDocumentsRequest(
        parent=parent, requests=requests
    )

    operation = client.batch_process_documents(batch_request)

    # Wait for the operation to finish
    operation.result()

    # Results are written to GCS. Use a regex to find
    # output files
    match = re.match(r'gs://([^/]+)/(.+)', destination_uri)
    output_bucket = match.group(1)
    prefix = match.group(2)

    storage_client = storage.client.Client()
    bucket = storage_client.get_bucket(output_bucket)
    blob_list = list(bucket.list_blobs(prefix=prefix))
    print('Output files:')
    for blob in blob_list:
        print(blob.name)

# %%
batch_parse_table(project_id="project-001-285307",input_uri="gs://bucket0406/invoice.pdf",destination_uri="gs://bucket0406/invoice_output.pdf")
# Out:
# Output files:
# invoice_output.pdf-output-page-1-to-1.json

# %% [markdown]
# It stores output as a JSON file in a specified Cloud Storage bucket.
